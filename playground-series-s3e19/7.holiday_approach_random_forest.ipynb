# %% [markdown]
# # Naive approach random_forest + optuna - holidays

# %%
model_name = 'random_forest_with_holidays'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data_path = "./data/"
df_train = pd.read_csv(data_path + "train.csv")
df_test = pd.read_csv(data_path + "test.csv")

# drop id
df_train.drop('id', axis=1, inplace=True)

df_train.head(10)
# Out:
#          date    country         store  \
# 0  2017-01-01  Argentina  Kaggle Learn
# 1  2017-01-01  Argentina  Kaggle Learn
# 2  2017-01-01  Argentina  Kaggle Learn
# 3  2017-01-01  Argentina  Kaggle Learn
# 4  2017-01-01  Argentina  Kaggle Learn
# 5  2017-01-01  Argentina  Kaggle Store
# 6  2017-01-01  Argentina  Kaggle Store
# 7  2017-01-01  Argentina  Kaggle Store
# 8  2017-01-01  Argentina  Kaggle Store
# 9  2017-01-01  Argentina  Kaggle Store
#
#                                           product  num_sold
# 0               Using LLMs to Improve Your Coding        63
# 1                   Using LLMs to Train More LLMs        66
# 2  Using LLMs to Win Friends and Influence People         9
# 3      Using LLMs to Win More Kaggle Competitions        59
# 4                      Using LLMs to Write Better        49
# 5               Using LLMs to Improve Your Coding        88
# 6                   Using LLMs to Train More LLMs        98
# 7  Using LLMs to Win Friends and Influence People        14
# 8      Using LLMs to Win More Kaggle Competitions        83
# 9                      Using LLMs to Write Better        69

# %% [markdown]
# ### Features

# %%
import holidays

def transform_date(df):
    df['date'] = pd.to_datetime(df['date'])
    return df

def create_features(df):
    # split date into year, month, day
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['day'] = df['date'].dt.day

    # week number
    df['week_number'] = df['date'].dt.isocalendar().week.astype(int)
    
    # day of week
    df['dayofweek'] = df['date'].dt.dayofweek

    # weekend
    df['weekend'] = (df['date'].dt.weekday >=4).astype(int)

    # drop date
    #df = df.drop('date', axis=1)

    # one-hot encoding of 'country', 'store', 'product' columns
    #df_train = pd.get_dummies(df_train, columns=['country', 'store', 'product'])


    df['country'] = df['country'].astype('category')
    df['store'] = df['store'].astype('category')
    df['product'] = df['product'].astype('category')

    return df

def encode_cat_variables(df):
    categorical_features = ["country", "store", "product"]
    df = pd.get_dummies(df, columns=categorical_features)
    return df

def add_holidays(df):
    # courtesy of kacperrabczewski in https://www.kaggle.com/code/kacperrabczewski/last-minute-forecasting#Modeling-%F0%9F%AA%84

    years_list = [2017, 2018, 2019, 2020, 2021, 2022, 2023]

    Argentina_holidays = holidays.CountryHoliday('AR', years=years_list)
    Canada_holidays = holidays.CountryHoliday('CA', years=years_list)
    Estonia_holidays = holidays.CountryHoliday('EE', years=years_list)
    Japan_holidays = holidays.CountryHoliday('JP', years=years_list)
    Spain_holidays = holidays.CountryHoliday('ES', years=years_list)
    
    # Create Holiday Column 
    df['Argentina_holiday'] = df.loc[df['country'] == 'Argentina', 'date'].apply(lambda d: True if d in Argentina_holidays else False)
    df['Canada_holiday'] = df.loc[df['country'] == 'Canada', 'date'].apply(lambda d: True if d in Canada_holidays else False)
    df['Estonia_holiday'] = df.loc[df['country'] == 'Estonia', 'date'].apply(lambda d: True if d in Estonia_holidays else False)
    df['Japan_holiday'] = df.loc[df['country'] == 'Japan', 'date'].apply(lambda d: True if d in Japan_holidays else False)
    df['Spain_holiday'] = df.loc[df['country'] == 'Spain', 'date'].apply(lambda d: True if d in Spain_holidays else False)

    df['Argentina_holiday'] = df['Argentina_holiday'].fillna(False)
    df['Canada_holiday'] = df['Canada_holiday'].fillna(False)
    df['Estonia_holiday'] = df['Estonia_holiday'].fillna(False)
    df['Japan_holiday'] = df['Japan_holiday'].fillna(False)
    df['Spain_holiday'] = df['Spain_holiday'].fillna(False)

    df = df.drop('date', axis=1)

    return df

df_train_0 = transform_date(df_train)
df_train_0 = create_features(df_train_0)
df_train_0 = add_holidays(df_train_0)
df_train_0 = encode_cat_variables(df_train_0)
df_train_0.head()
# Out:
#    num_sold  year  month  day  week_number  dayofweek  weekend  \
# 0        63  2017      1    1           52          6        1
# 1        66  2017      1    1           52          6        1
# 2         9  2017      1    1           52          6        1
# 3        59  2017      1    1           52          6        1
# 4        49  2017      1    1           52          6        1
#
#    Argentina_holiday  Canada_holiday  Estonia_holiday  ...  country_Japan  \
# 0               True           False            False  ...          False
# 1               True           False            False  ...          False
# 2               True           False            False  ...          False
# 3               True           False            False  ...          False
# 4               True           False            False  ...          False
#
#    country_Spain  store_Kagglazon  store_Kaggle Learn  store_Kaggle Store  \
# 0          False            False                True               False
# 1          False            False                True               False
# 2          False            False                True               False
# 3          False            False                True               False
# 4          False            False                True               False
#
#    product_Using LLMs to Improve Your Coding  \
# 0                                       True
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    product_Using LLMs to Train More LLMs  \
# 0                                  False
# 1                                   True
# 2                                  False
# 3                                  False
# 4                                  False
#
#    product_Using LLMs to Win Friends and Influence People  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#    product_Using LLMs to Win More Kaggle Competitions  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    product_Using LLMs to Write Better
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                                True
#
# [5 rows x 25 columns]

# %%
model_features = df_train_0.columns.tolist()
model_features.remove("num_sold")
model_features
# Out:
# ['year',
#  'month',
#  'day',
#  'week_number',
#  'dayofweek',
#  'weekend',
#  'Argentina_holiday',
#  'Canada_holiday',
#  'Estonia_holiday',
#  'Japan_holiday',
#  'Spain_holiday',
#  'country_Argentina',
#  'country_Canada',
#  'country_Estonia',
#  'country_Japan',
#  'country_Spain',
#  'store_Kagglazon',
#  'store_Kaggle Learn',
#  'store_Kaggle Store',
#  'product_Using LLMs to Improve Your Coding',
#  'product_Using LLMs to Train More LLMs',
#  'product_Using LLMs to Win Friends and Influence People',
#  'product_Using LLMs to Win More Kaggle Competitions',
#  'product_Using LLMs to Write Better']

# %%
df_train_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136950 entries, 0 to 136949
# Data columns (total 25 columns):
#  #   Column                                                  Non-Null Count   Dtype
# ---  ------                                                  --------------   -----
#  0   num_sold                                                136950 non-null  int64
#  1   year                                                    136950 non-null  int32
#  2   month                                                   136950 non-null  int32
#  3   day                                                     136950 non-null  int32
#  4   week_number                                             136950 non-null  int32
#  5   dayofweek                                               136950 non-null  int32
#  6   weekend                                                 136950 non-null  int32
#  7   Argentina_holiday                                       136950 non-null  bool
#  8   Canada_holiday                                          136950 non-null  bool
#  9   Estonia_holiday                                         136950 non-null  bool
#  10  Japan_holiday                                           136950 non-null  bool
#  11  Spain_holiday                                           136950 non-null  bool
#  12  country_Argentina                                       136950 non-null  bool
#  13  country_Canada                                          136950 non-null  bool
#  14  country_Estonia                                         136950 non-null  bool
#  15  country_Japan                                           136950 non-null  bool
#  16  country_Spain                                           136950 non-null  bool
#  17  store_Kagglazon                                         136950 non-null  bool
#  18  store_Kaggle Learn                                      136950 non-null  bool
#  19  store_Kaggle Store                                      136950 non-null  bool
#  20  product_Using LLMs to Improve Your Coding               136950 non-null  bool
#  21  product_Using LLMs to Train More LLMs                   136950 non-null  bool
#  22  product_Using LLMs to Win Friends and Influence People  136950 non-null  bool
#  23  product_Using LLMs to Win More Kaggle Competitions      136950 non-null  bool
#  24  product_Using LLMs to Write Better                      136950 non-null  bool
# dtypes: bool(18), int32(6), int64(1)
# memory usage: 6.5 MB

# %% [markdown]
# Function by which submissions are scored is SMAPE:

# %%
def SMAPE(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.ensemble import RandomForestRegressor
import optuna

train_index, val_index = [ x for x in TimeSeriesSplit(n_splits=5).split(df_train_0) ][-1]

X_train = df_train_0.iloc[train_index][model_features]
y_train = df_train_0.iloc[train_index]['num_sold']

X_val = df_train_0.iloc[val_index][model_features]
y_val = df_train_0.iloc[val_index]['num_sold']

cat_features_indices = np.where((X_train.dtypes == "category") | (X_train.dtypes == "object"))[0]
cat_features_indices

def objective(trial):
    model = RandomForestRegressor(
        n_estimators=trial.suggest_int('n_estimators', 100, 1000),
        max_depth=trial.suggest_int('max_depth', 10, 110),
        bootstrap=trial.suggest_categorical('bootstrap', [True, False]),
        min_samples_leaf=trial.suggest_categorical('min_samples_leaf', [1, 2, 4]),
        min_samples_split=trial.suggest_categorical('min_samples_split', [2, 5, 10]),
        max_features=trial.suggest_categorical('max_features', ['sqrt', 'log2']),
        random_state=42,
        n_jobs=-1
    )
    
    model.fit(
        X_train, y_train,
    )

    return SMAPE(y_val, np.round(model.predict(X_val)))


study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=60)

best_hyperparams = study.best_params
# Out:
# [I 2023-07-29 17:35:56,094] A new study created in memory with name: no-name-58b725a9-05f7-4ba7-ba10-95e45bd15d16
# [I 2023-07-29 17:36:01,853] Trial 0 finished with value: 11.303095078915641 and parameters: {'n_estimators': 391, 'max_depth': 63, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 0 with value: 11.303095078915641.
# [I 2023-07-29 17:36:13,191] Trial 1 finished with value: 11.235018874590962 and parameters: {'n_estimators': 841, 'max_depth': 23, 'bootstrap': True, 'min_samples_leaf': 2, 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 1 with value: 11.235018874590962.
# [I 2023-07-29 17:36:27,311] Trial 2 finished with value: 11.798434942417622 and parameters: {'n_estimators': 786, 'max_depth': 24, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 1 with value: 11.235018874590962.
# [I 2023-07-29 17:36:36,710] Trial 3 finished with value: 11.21483806983886 and parameters: {'n_estimators': 735, 'max_depth': 62, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 3 with value: 11.21483806983886.
# [I 2023-07-29 17:36:48,545] Trial 4 finished with value: 11.505019952007489 and parameters: {'n_estimators': 984, 'max_depth': 46, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 3 with value: 11.21483806983886.
# [I 2023-07-29 17:36:50,629] Trial 5 finished with value: 11.062129406019965 and parameters: {'n_estimators': 167, 'max_depth': 67, 'bootstrap': True, 'min_samples_leaf': 2, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 5 with value: 11.062129406019965.
# [I 2023-07-29 17:36:52,467] Trial 6 finished with value: 14.238666237400622 and parameters: {'n_estimators': 385, 'max_depth': 11, 'bootstrap': True, 'min_samples_leaf': 4, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 5 with value: 11.062129406019965.
# [I 2023-07-29 17:36:55,878] Trial 7 finished with value: 13.52890345443402 and parameters: {'n_estimators': 742, 'max_depth': 11, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 5 with value: 11.062129406019965.
# [I 2023-07-29 17:37:00,770] Trial 8 finished with value: 10.910043909198523 and parameters: {'n_estimators': 441, 'max_depth': 20, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:08,763] Trial 9 finished with value: 11.508565221587464 and parameters: {'n_estimators': 716, 'max_depth': 94, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:20,716] Trial 10 finished with value: 12.084087546476963 and parameters: {'n_estimators': 508, 'max_depth': 101, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:22,182] Trial 11 finished with value: 11.203907199357454 and parameters: {'n_estimators': 116, 'max_depth': 77, 'bootstrap': True, 'min_samples_leaf': 2, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:23,995] Trial 12 finished with value: 11.056388357933002 and parameters: {'n_estimators': 130, 'max_depth': 43, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:28,137] Trial 13 finished with value: 11.170715771602177 and parameters: {'n_estimators': 287, 'max_depth': 42, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:35,612] Trial 14 finished with value: 11.208046871726568 and parameters: {'n_estimators': 564, 'max_depth': 43, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:39,023] Trial 15 finished with value: 10.978058179330525 and parameters: {'n_estimators': 252, 'max_depth': 30, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:44,997] Trial 16 finished with value: 12.042776611110295 and parameters: {'n_estimators': 269, 'max_depth': 27, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:52,659] Trial 17 finished with value: 11.143887079333687 and parameters: {'n_estimators': 583, 'max_depth': 32, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:37:58,698] Trial 18 finished with value: 11.162013429047569 and parameters: {'n_estimators': 437, 'max_depth': 33, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:38:05,317] Trial 19 finished with value: 11.982713161204105 and parameters: {'n_estimators': 281, 'max_depth': 53, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 8 with value: 10.910043909198523.
# [I 2023-07-29 17:38:09,109] Trial 20 finished with value: 9.999877231849428 and parameters: {'n_estimators': 475, 'max_depth': 16, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:12,167] Trial 21 finished with value: 10.28953180474754 and parameters: {'n_estimators': 333, 'max_depth': 17, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:16,872] Trial 22 finished with value: 10.363654910184588 and parameters: {'n_estimators': 485, 'max_depth': 17, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:22,414] Trial 23 finished with value: 10.02750259648553 and parameters: {'n_estimators': 630, 'max_depth': 16, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:25,708] Trial 24 finished with value: 13.528485717325449 and parameters: {'n_estimators': 634, 'max_depth': 11, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:34,414] Trial 25 finished with value: 11.196716731672819 and parameters: {'n_estimators': 630, 'max_depth': 35, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:38,334] Trial 26 finished with value: 10.714041612858678 and parameters: {'n_estimators': 347, 'max_depth': 19, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'sqrt'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:45,642] Trial 27 finished with value: 11.24200194027763 and parameters: {'n_estimators': 526, 'max_depth': 73, 'bootstrap': True, 'min_samples_leaf': 1, 'min_samples_split': 5, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:51,202] Trial 28 finished with value: 10.661427094270836 and parameters: {'n_estimators': 641, 'max_depth': 54, 'bootstrap': True, 'min_samples_leaf': 4, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:38:54,678] Trial 29 finished with value: 10.084190225241409 and parameters: {'n_estimators': 387, 'max_depth': 16, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:00,743] Trial 30 finished with value: 11.255632947890458 and parameters: {'n_estimators': 444, 'max_depth': 37, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:04,300] Trial 31 finished with value: 10.249173412840051 and parameters: {'n_estimators': 356, 'max_depth': 17, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:07,103] Trial 32 finished with value: 11.174039020757272 and parameters: {'n_estimators': 205, 'max_depth': 23, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:08,736] Trial 33 finished with value: 16.494768682503945 and parameters: {'n_estimators': 366, 'max_depth': 10, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:14,082] Trial 34 finished with value: 11.17704590542474 and parameters: {'n_estimators': 419, 'max_depth': 26, 'bootstrap': False, 'min_samples_leaf': 1, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:18,191] Trial 35 finished with value: 10.179337627367401 and parameters: {'n_estimators': 487, 'max_depth': 16, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:29,465] Trial 36 finished with value: 11.295054197867918 and parameters: {'n_estimators': 910, 'max_depth': 23, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:35,575] Trial 37 finished with value: 11.255388681674658 and parameters: {'n_estimators': 482, 'max_depth': 38, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:48,379] Trial 38 finished with value: 12.024155728182121 and parameters: {'n_estimators': 692, 'max_depth': 28, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 2, 'max_features': 'log2'}. Best is trial 20 with value: 9.999877231849428.
# [I 2023-07-29 17:39:52,878] Trial 39 finished with value: 9.803270882496674 and parameters: {'n_estimators': 594, 'max_depth': 15, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 39 with value: 9.803270882496674.
# [I 2023-07-29 17:40:02,649] Trial 40 finished with value: 11.206206876125915 and parameters: {'n_estimators': 805, 'max_depth': 90, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 39 with value: 9.803270882496674.
# [I 2023-07-29 17:40:07,112] Trial 41 finished with value: 9.807145835585494 and parameters: {'n_estimators': 599, 'max_depth': 15, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 39 with value: 9.803270882496674.
# [I 2023-07-29 17:40:11,175] Trial 42 finished with value: 9.765224085662108 and parameters: {'n_estimators': 600, 'max_depth': 14, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:40:18,572] Trial 43 finished with value: 11.165357677460149 and parameters: {'n_estimators': 599, 'max_depth': 22, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:40:21,608] Trial 44 finished with value: 16.607667017016713 and parameters: {'n_estimators': 694, 'max_depth': 10, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:40:26,626] Trial 45 finished with value: 9.775337554920634 and parameters: {'n_estimators': 757, 'max_depth': 14, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:40:31,866] Trial 46 finished with value: 10.297655022155338 and parameters: {'n_estimators': 867, 'max_depth': 13, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:40:41,132] Trial 47 finished with value: 11.107400564890083 and parameters: {'n_estimators': 768, 'max_depth': 22, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:40:53,838] Trial 48 finished with value: 11.242611729345825 and parameters: {'n_estimators': 981, 'max_depth': 30, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:02,508] Trial 49 finished with value: 11.223455283804723 and parameters: {'n_estimators': 672, 'max_depth': 26, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 10, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:06,279] Trial 50 finished with value: 9.781446993467183 and parameters: {'n_estimators': 545, 'max_depth': 14, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:10,035] Trial 51 finished with value: 9.782331224959353 and parameters: {'n_estimators': 549, 'max_depth': 14, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:13,209] Trial 52 finished with value: 10.333704836102152 and parameters: {'n_estimators': 537, 'max_depth': 13, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:19,818] Trial 53 finished with value: 11.262396856940146 and parameters: {'n_estimators': 569, 'max_depth': 21, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:24,184] Trial 54 finished with value: 10.296134231436383 and parameters: {'n_estimators': 745, 'max_depth': 13, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:31,378] Trial 55 finished with value: 11.484682933581768 and parameters: {'n_estimators': 596, 'max_depth': 107, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:37,332] Trial 56 finished with value: 11.098606147167157 and parameters: {'n_estimators': 541, 'max_depth': 20, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:45,055] Trial 57 finished with value: 11.472705154084446 and parameters: {'n_estimators': 662, 'max_depth': 26, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 42 with value: 9.765224085662108.
# [I 2023-07-29 17:41:49,296] Trial 58 finished with value: 9.740850612630766 and parameters: {'n_estimators': 590, 'max_depth': 14, 'bootstrap': False, 'min_samples_leaf': 2, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 58 with value: 9.740850612630766.
# [I 2023-07-29 17:41:58,304] Trial 59 finished with value: 11.521513219150679 and parameters: {'n_estimators': 724, 'max_depth': 49, 'bootstrap': False, 'min_samples_leaf': 4, 'min_samples_split': 2, 'max_features': 'sqrt'}. Best is trial 58 with value: 9.740850612630766.

# %%
best_hyperparams
# Out:
# {'n_estimators': 590,
#  'max_depth': 14,
#  'bootstrap': False,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'max_features': 'sqrt'}

# %%
# split into train and validation

results_smape = []
results_r2 = []
results_mse = []


N_SPLITS = 5

for train_index, val_index in TimeSeriesSplit(n_splits=N_SPLITS).split(df_train_0):
    X_train = df_train_0.iloc[train_index][model_features]
    y_train = df_train_0.iloc[train_index]['num_sold']

    X_val = df_train_0.iloc[val_index]
    y_val = df_train_0.iloc[val_index]['num_sold']

    model = RandomForestRegressor(**best_hyperparams)
    model.fit(X_train, y_train)

    # evaluate on validation set
    y_pred = np.round(model.predict(X_val[model_features]))

    smape = SMAPE(y_val, y_pred)
    r2 = r2_score(y_val, y_pred)
    mse = mean_squared_error(y_val, y_pred)

    results_smape.append(smape)
    results_r2.append(r2)
    results_mse.append(mse)
    del model

print("Cross validated results:")

print("SMAPE: %s" % results_smape)
print("R2: %s" % results_r2)
print("MSE: %s" % results_mse)

print("Mean results:")
print("SMAPE: %.4f" % np.mean(results_smape))
print("R2: %.4f" % np.mean(results_r2))
print("MSE: %.4f" % np.mean(results_mse))


# add a row with results to csv file leaderboard.csv

row = [model_name, np.mean(results_smape), np.mean(results_r2), np.mean(results_mse)]
with open('leaderboard.csv', 'a') as fd:
    import csv
    fd.write('\n')
    writer = csv.writer(fd, delimiter=',', lineterminator=';\n')
    writer.writerow(row)
# Out:
# Cross validated results:
# SMAPE: [12.478682702508127, 11.335914189389783, 15.720086532580133, 11.734515580483093, 9.788766527545397]
# R2: [0.9651878204361477, 0.9823804132855994, 0.9651845500614605, 0.9675530101398672, 0.9616523865157246]
# MSE: [1227.41708652793, 615.3574151150054, 1095.3174589266155, 1024.7362541073385, 1502.7780065717416]
# Mean results:
# SMAPE: 12.2116
# R2: 0.9684
# MSE: 1093.1212

# %%
# train and predict for submission

df_train = pd.read_csv(data_path + "train.csv")
df_train['date'] = pd.to_datetime(df_train['date'])

df_train_0 = transform_date(df_train)
df_train_0 = create_features(df_train_0)
df_train_0 = add_holidays(df_train_0)
df_train_0 = encode_cat_variables(df_train_0)

X_train = df_train_0.drop('num_sold', axis=1)
y_train = df_train_0['num_sold']



model = RandomForestRegressor(**best_hyperparams)
model.fit(X_train[model_features], y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=14, max_features='sqrt',
#                       min_samples_leaf=2, n_estimators=590)

# %%
import datetime
X_train['date'] = pd.to_datetime(X_train['year'].astype(str) + '-' + X_train['month'].astype(str) + '-' + X_train['day'].astype(str))
X_val['date'] = pd.to_datetime(X_val['year'].astype(str) + '-' + X_val['month'].astype(str) + '-' + X_val['day'].astype(str))
df_val['date'] = pd.to_datetime(df_val['year'].astype(str) + '-' + df_val['month'].astype(str) + '-' + df_val['day'].astype(str))

# sort by date
X_train.sort_values(by='date', inplace=True)
X_val.sort_values(by='date', inplace=True)

# plot 'num_sold' vs 'date'
fig, ax = plt.subplots(figsize=(15, 5))

ax.plot(X_train['date'], y_train, label='train', color='lightblue')
ax.plot(X_val['date'], y_val, label='validation', color='pink')
ax.plot(df_val['date'], df_val['prediction'], label='prediction', color='crimson')

# x axis show only from 2021 onwards
ax.set_xlim([datetime.date(2021, 1, 1), df_val['date'].max()])
ax.set_xlabel('date')
ax.set_ylabel('num_sold')

ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Wiktor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Wiktor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Wiktor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 4
#       2 X_train['date'] = pd.to_datetime(X_train['year'].astype(str) + '-' + X_train['month'].astype(str) + '-' + X_train['day'].astype(str))
#       3 X_val['date'] = pd.to_datetime(X_val['year'].astype(str) + '-' + X_val['month'].astype(str) + '-' + X_val['day'].astype(str))
# ----> 4 df_val['date'] = pd.to_datetime(df_val['year'].astype(str) + '-' + df_val['month'].astype(str) + '-' + df_val['day'].astype(str))
#       6 # sort by date
#       7 X_train.sort_values(by='date', inplace=True)
#
# File c:\Users\Wiktor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Wiktor\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'year'

# %%
# test 

df_test = pd.read_csv(data_path + "test.csv")

df_test_0 = transform_date(df_test)
df_test_0 = create_features(df_test_0)
df_test_0 = add_holidays(df_test_0)
df_test_0 = encode_cat_variables(df_test_0)

# predict for test set
df_test['prediction'] = model.predict(df_test_0[model_features])
df_test['prediction'] = df_test['prediction'].astype(int)
df_test
# Out:
#            id       date    country         store  \
# 0      136950 2022-01-01  Argentina  Kaggle Learn
# 1      136951 2022-01-01  Argentina  Kaggle Learn
# 2      136952 2022-01-01  Argentina  Kaggle Learn
# 3      136953 2022-01-01  Argentina  Kaggle Learn
# 4      136954 2022-01-01  Argentina  Kaggle Learn
# ...       ...        ...        ...           ...
# 27370  164320 2022-12-31      Spain     Kagglazon
# 27371  164321 2022-12-31      Spain     Kagglazon
# 27372  164322 2022-12-31      Spain     Kagglazon
# 27373  164323 2022-12-31      Spain     Kagglazon
# 27374  164324 2022-12-31      Spain     Kagglazon
#
#                                               product  year  month  day  \
# 0                   Using LLMs to Improve Your Coding  2022      1    1
# 1                       Using LLMs to Train More LLMs  2022      1    1
# 2      Using LLMs to Win Friends and Influence People  2022      1    1
# 3          Using LLMs to Win More Kaggle Competitions  2022      1    1
# 4                          Using LLMs to Write Better  2022      1    1
# ...                                               ...   ...    ...  ...
# 27370               Using LLMs to Improve Your Coding  2022     12   31
# 27371                   Using LLMs to Train More LLMs  2022     12   31
# 27372  Using LLMs to Win Friends and Influence People  2022     12   31
# 27373      Using LLMs to Win More Kaggle Competitions  2022     12   31
# 27374                      Using LLMs to Write Better  2022     12   31
#
#        week_number  dayofweek  weekend  Argentina_holiday  Canada_holiday  \
# 0               52          5        1               True           False
# 1               52          5        1               True           False
# 2               52          5        1               True           False
# 3               52          5        1               True           False
# 4               52          5        1               True           False
# ...            ...        ...      ...                ...             ...
# 27370           52          5        1              False           False
# 27371           52          5        1              False           False
# 27372           52          5        1              False           False
# 27373           52          5        1              False           False
# 27374           52          5        1              False           False
#
#        Estonia_holiday  Japan_holiday  Spain_holiday  prediction
# 0                False          False          False          36
# 1                False          False          False          37
# 2                False          False          False           6
# 3                False          False          False          35
# 4                False          False          False          29
# ...                ...            ...            ...         ...
# 27370            False          False          False         623
# 27371            False          False          False         631
# 27372            False          False          False         112
# 27373            False          False          False         586
# 27374            False          False          False         465
#
# [27375 rows x 17 columns]

# %%
df_test['num_sold'] = df_test['prediction']
df_test[['id', 'num_sold']].to_csv(f'{model_name}_submission.csv', index=False)
print(f'{model_name}_submission.csv saved')
# Out:
# random_forest_with_holidays_submission.csv saved

# %%
! kaggle competitions submit -c playground-series-s3e19 -f random_forest_with_holidays_submission.csv -m "random_forest_with_holidays"
