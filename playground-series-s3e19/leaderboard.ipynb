# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_csv('leaderboard.csv')

# remove duplicates
#df = df.drop_duplicates()
df.sort_values(by=['mean_smape'], inplace=True, ascending=True)
df
# Out:
#                                            model_name  mean_smape   mean_r2  \
# 13                random_forest_with_holidays_no_2020    9.473514  0.979936
# 12                      naive_approach_xgboost_optuna   11.086357  0.971968
# 2                       naive_approach_xgboost_optuna   11.154479  0.972579
# 8                         random_forest_with_holidays   12.211593  0.968392
# 6                         random_forest_with_holidays   12.374106  0.964077
# 3                                       random_forest   12.377905  0.963940
# 5                                       random_forest   12.381628  0.964118
# 4                                       random_forest   12.396540  0.964108
# 9    random_forest_with_holidays_seasonality_features   12.927055  0.967657
# 7                 random_forest_with_holidays_no_year   13.536103  0.967210
# 10  default_xgboost_with_holidays_seasonality_feat...   13.689658  0.968418
# ...

# %%
best_model = df.head(1)['model_name'].values[0]

f"Current best model: {best_model}"
# Out:
# 'Current best model: random_forest_with_holidays_no_2020'
