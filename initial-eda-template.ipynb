# %% [markdown]
# # Initial EDA - <fill competition name>

# %% [markdown]
# # 1. Intruction
#
# ### Why do we do this?
#
# > Fill explanation here, creating a model without understanding its context is worthless.
#
#
# #### 2. What we need to predict
#
# - fill goal here
#
# #### 3. Evaluation
#
# fill evaluation metric here, example:
#
# **Average of the sample weighted log losses** from each injury type and an any_injury prediction generated by the metric
#
# $$\text{Weighted Average Log Loss} = \frac{\sum_{i=1}^{n} w_i \cdot \text{LogLoss}_i}{\sum_{i=1}^{n} w_i}$$
#
#
# - $n$ is the number of features
# - $w_i$ is the weight associated with feature $i$. Feature weights are shown in the table below:
#
# ### 📚 **Libraries**

# %%
# essentials
import os
import pathlib

import pandas as pd
import numpy as np
from tqdm import tqdm

# visualisation
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn imports
from sklearn.model_selection import train_test_split
import xgboost as xgb
