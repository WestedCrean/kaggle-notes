# %% [markdown]
# # Hyperparameter optimization with Ray
#
# ## Libraries

# %%
# essentials
import os
import pathlib

import pandas as pd
import numpy as np
from tqdm import tqdm

# visualisation
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn imports
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MaxAbsScaler, PowerTransformer, FunctionTransformer, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest, chi2, f_classif, SequentialFeatureSelector, RFECV
from sklearn.calibration import CalibratedClassifierCV
from sklearn.base import clone as clone_model
from sklearn.metrics import classification_report, confusion_matrix, log_loss


from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier, ExtraTreesClassifier, BaggingClassifier, StackingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, ComplementNB

# others
import xgboost as xgb 
import lightgbm as lgb
import catboost as cb

# ray imports
import joblib
import ray
from ray.util.joblib import register_ray

RANDOM_SEED = 64
# Out:
# 2023-12-15 14:20:03,096	INFO util.py:159 -- Outdated packages:
#   ipywidgets==7.8.0 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# ## Setup

# %%
IN_KAGGLE = False
kaggle_folder = "/kaggle/input/playground-series-s3e26"
local_folder = "./data"
train_df = pd.read_csv(kaggle_folder if IN_KAGGLE else local_folder + "/train.csv", index_col="id")
test_df = pd.read_csv(kaggle_folder if IN_KAGGLE else local_folder  + "/test.csv", index_col="id")

target_column = "Status"

# %%
def feature_engineering(df):
    #train_df['Status'] = train_df['Status'].map({"D": 0,"C": 1,"CL": 2})
    df['date_of_diagnosis'] = df['Age'] - df['N_Days']
    
    df['no_diseases'] = (df['Ascites'] + df['Hepatomegaly'] + df['Spiders'] + df['Edema']) == 0
    df['diseases'] = df['Ascites'] + df['Hepatomegaly'] + df['Spiders'] + df['Edema']
    df['Drug'] = df['Drug'].map({"D-penicillamine": 1,"placebo": 0})

    # change "Stage" to string
    df["Stage"] = df["Stage"].apply(lambda x: str(x))
    return df

train_df = pd.read_csv(kaggle_folder if IN_KAGGLE else local_folder + "/train.csv", index_col="id")

run_feature_engineering = True

categorical_features = ["Drug", "Sex", "Ascites", "Hepatomegaly", "Spiders", "Edema", "Stage"]
numerical_features = ["N_Days", "Age", "Bilirubin", "Cholesterol", "Albumin", "Copper", "Alk_Phos", "SGOT", "Tryglicerides", "Platelets", "Prothrombin"]

if run_feature_engineering:
    train_df = feature_engineering(train_df)

if run_feature_engineering:
    categorical_features += ["no_diseases", "diseases"]
    numerical_features += ["date_of_diagnosis"]

for col in categorical_features:
    train_df[col] = train_df[col].astype("category")

X = train_df.drop(columns=target_column)
y = train_df[target_column]

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1, random_state=RANDOM_SEED, stratify=y, shuffle=True)

le = LabelEncoder()

y_train = le.fit_transform(y_train)
y_val = le.transform(y_val)

numeric_transformer = Pipeline(
    [
        ("power_transformer", PowerTransformer()),
        ("scaler", MaxAbsScaler()),
    ]
)

categorical_transformer = Pipeline(
    [
        ("onehot", OneHotEncoder(handle_unknown="ignore")),
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numerical_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

# %% [markdown]
# ## Parameter space

# %%
models = {
    "xgboost": xgb.XGBClassifier(objective="multi:softprob", num_class=len(le.classes_), random_state=RANDOM_SEED, n_jobs=4),
    "catboost": cb.CatBoostClassifier(random_state=RANDOM_SEED, verbose=False),
    #"lightgbm": lgb.LGBMClassifier(random_state=RANDOM_SEED, n_jobs=-1, num_threads=8, force_row_wise=True, early_stopping_round=5),
    "hist_gradient_boosting": HistGradientBoostingClassifier(random_state=RANDOM_SEED),
    "gradient_boosting": GradientBoostingClassifier(random_state=RANDOM_SEED),
    "knn": KNeighborsClassifier(n_jobs=4),

}

naive_bayes_models = {
    #"naive_bayes": GaussianNB(),
    "complement_naive_bayes": ComplementNB(),
    "complement_naive_bayes_bagging": BaggingClassifier(
        base_estimator=ComplementNB(alpha=0.9), 
        random_state=RANDOM_SEED, 
        n_jobs=4
    )
}

param_space = {
    "xgboost": {
        "classifier__eta": np.arange(0.01, 0.2, 0.01),
        "classifier__min_child_weight": np.arange(1, 10, 1),
        "classifier__max_depth": np.arange(3, 10, 1),
        "classifier__gamma": np.arange(0, 1, 0.1),
        "classifier__subsample": np.arange(0.5, 1, 0.1),
        "classifier__colsample_bytree": np.arange(0.5, 1, 0.1),
        "classifier__lambda": np.arange(0, 1, 0.1),
        "classifier__alpha": np.arange(0, 1, 0.1),
    },
    "catboost": {
        "classifier__learning_rate": np.arange(0.01, 0.2, 0.01),
        "classifier__depth": np.arange(3, 10, 1),
        "classifier__l2_leaf_reg": np.arange(1, 10, 1),
        "classifier__border_count": np.arange(1, 10, 1),
        "classifier__min_data_in_leaf": np.arange(1, 10, 1),
    },
    "lightgbm": {
        "classifier__num_leaves": np.arange(50, 100, 1),
        "classifier__max_depth": np.arange(3, 10, 1),
        "classifier__min_data_in_leaf": np.arange(50, 1000, 10),
    },
    "hist_gradient_boosting": {
        "classifier__learning_rate": np.arange(0.01, 0.2, 0.01),
        "classifier__max_depth": np.arange(3, 10, 1),
        "classifier__min_samples_leaf": np.arange(1, 10, 1),
        "classifier__max_leaf_nodes": np.arange(2, 10, 1),
    },
    "gradient_boosting": {
        "classifier__learning_rate": np.arange(0.01, 0.2, 0.01),
        "classifier__max_depth": np.arange(3, 10, 1),
        "classifier__min_samples_leaf": np.arange(1, 10, 1),
        "classifier__max_leaf_nodes": np.arange(2, 10, 1),
    },
    "naive_bayes": {
        "classifier__var_smoothing": np.arange(1e-9, 1e-8, 1e-9),
    },
    "complement_naive_bayes": {
        "classifier__alpha": np.arange(0.8, 1.0, 0.01),
    },
    "complement_naive_bayes_bagging": {
        "classifier__n_estimators": np.arange(10, 200, 10),
        "classifier__max_samples": np.arange(0.1, 1, 0.1),
    },
    "knn": {
        "classifier__n_neighbors": np.arange(15, 30, 1),
        "classifier__weights": ["uniform", "distance"],
        "classifier__leaf_size": np.arange(1, 10, 1),
        "classifier__p": np.arange(1, 10, 1),
    },
}

output_params = {}
output_scores = {}
output_best_esimators = {}

# %%
register_ray()

for model_name, model in models.items():
    clf = Pipeline(
        [
            ("preprocessor", preprocessor),
            ("classifier", model),
        ]
    )
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=RANDOM_SEED)

    model_param_space = param_space[model_name]
    search = RandomizedSearchCV(clf, model_param_space, cv=skf, n_iter=150, verbose=10, scoring="neg_log_loss")


    with joblib.parallel_backend('ray'):
        search.fit(X_train, y_train)

    output_params[model_name] = search.best_params_
    output_scores[model_name] = search.best_score_
    output_best_esimators[model_name] = search.best_estimator_
# Out:
# 2023-12-15 14:20:03,322	INFO ray_backend.py:74 -- Starting local ray cluster
# 2023-12-15 14:20:05,373	INFO worker.py:1664 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 2023-12-15 14:20:06,401	WARNING pool.py:589 -- The 'context' argument is not supported using ray. Please refer to the documentation for how to control ray initialization.
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# (PoolActor pid=6323) [CV 3/3; 4/150] START classifier__alpha=0.2, classifier__colsample_bytree=0.5, classifier__eta=0.04, classifier__gamma=0.5, classifier__lambda=0.4, classifier__max_depth=6, classifier__min_child_weight=9, classifier__subsample=0.8999999999999999
# (PoolActor pid=6300) [CV 1/3; 2/150] END classifier__alpha=0.9, classifier__colsample_bytree=0.7, classifier__eta=0.09999999999999999, classifier__gamma=0.9, classifier__lambda=0.5, classifier__max_depth=3, classifier__min_child_weight=2, classifier__subsample=0.8999999999999999;, score=-0.441 total time=   2.0s
# (PoolActor pid=6309) [CV 2/3; 13/150] START classifier__alpha=0.1, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.03, classifier__gamma=0.8, classifier__lambda=0.0, classifier__max_depth=4, classifier__min_child_weight=3, classifier__subsample=0.5 [repeated 29x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (PoolActor pid=6309) [CV 2/3; 13/150] END classifier__alpha=0.1, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.03, classifier__gamma=0.8, classifier__lambda=0.0, classifier__max_depth=4, classifier__min_child_weight=3, classifier__subsample=0.5;, score=-0.493 total time=   3.0s [repeated 19x across cluster]
# (PoolActor pid=6324) [CV 3/3; 15/150] START classifier__alpha=0.8, classifier__colsample_bytree=0.7, classifier__eta=0.03, classifier__gamma=0.7000000000000001, classifier__lambda=0.6000000000000001, classifier__max_depth=9, classifier__min_child_weight=8, classifier__subsample=0.6 [repeated 18x across cluster]
# (PoolActor pid=6298) [CV 3/3; 22/150] END classifier__alpha=0.6000000000000001, classifier__colsample_bytree=0.6, classifier__eta=0.01, classifier__gamma=0.0, classifier__lambda=0.7000000000000001, classifier__max_depth=6, classifier__min_child_weight=7, classifier__subsample=0.7;, score=-0.664 total time=   3.1s [repeated 28x across cluster]
# (PoolActor pid=6300) [CV 2/3; 23/150] START classifier__alpha=0.2, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.18000000000000002, classifier__gamma=0.9, classifier__lambda=0.30000000000000004, classifier__max_depth=3, classifier__min_child_weight=7, classifier__subsample=0.7 [repeated 25x across cluster]
# (PoolActor pid=6321) [CV 2/3; 25/150] END classifier__alpha=0.2, classifier__colsample_bytree=0.6, classifier__eta=0.060000000000000005, classifier__gamma=0.2, classifier__lambda=0.5, classifier__max_depth=5, classifier__min_child_weight=5, classifier__subsample=0.8999999999999999;, score=-0.458 total time=   2.5s [repeated 22x across cluster]
# (PoolActor pid=6321) [CV 1/3; 36/150] START classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.13, classifier__gamma=0.30000000000000004, classifier__lambda=0.8, classifier__max_depth=4, classifier__min_child_weight=9, classifier__subsample=0.5 [repeated 21x across cluster]
# (PoolActor pid=6320) [CV 2/3; 30/150] END classifier__alpha=0.1, classifier__colsample_bytree=0.5, classifier__eta=0.16, classifier__gamma=0.1, classifier__lambda=0.8, classifier__max_depth=3, classifier__min_child_weight=2, classifier__subsample=0.7999999999999999;, score=-0.453 total time=   1.4s [repeated 26x across cluster]
# (PoolActor pid=6301) [CV 3/3; 39/150] START classifier__alpha=0.6000000000000001, classifier__colsample_bytree=0.6, classifier__eta=0.11, classifier__gamma=0.0, classifier__lambda=0.4, classifier__max_depth=6, classifier__min_child_weight=7, classifier__subsample=0.7 [repeated 26x across cluster]
# (PoolActor pid=6325) [CV 2/3; 37/150] END classifier__alpha=0.5, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.09, classifier__gamma=0.5, classifier__lambda=0.30000000000000004, classifier__max_depth=7, classifier__min_child_weight=2, classifier__subsample=0.7;, score=-0.464 total time=   5.2s [repeated 25x across cluster]
# (PoolActor pid=6318) [CV 3/3; 45/150] START classifier__alpha=0.1, classifier__colsample_bytree=0.7, classifier__eta=0.13, classifier__gamma=0.30000000000000004, classifier__lambda=0.6000000000000001, classifier__max_depth=5, classifier__min_child_weight=5, classifier__subsample=0.7 [repeated 23x across cluster]
# (PoolActor pid=6324) [CV 2/3; 42/150] END classifier__alpha=0.8, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.18000000000000002, classifier__gamma=0.6000000000000001, classifier__lambda=0.5, classifier__max_depth=6, classifier__min_child_weight=1, classifier__subsample=0.7;, score=-0.477 total time=   4.4s [repeated 26x across cluster]
# (PoolActor pid=6318) [CV 2/3; 56/150] START classifier__alpha=0.8, classifier__colsample_bytree=0.7, classifier__eta=0.08, classifier__gamma=0.6000000000000001, classifier__lambda=0.8, classifier__max_depth=7, classifier__min_child_weight=5, classifier__subsample=0.7999999999999999 [repeated 25x across cluster]
# (PoolActor pid=6321) [CV 3/3; 62/150] END classifier__alpha=0.9, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.14, classifier__gamma=0.30000000000000004, classifier__lambda=0.6000000000000001, classifier__max_depth=5, classifier__min_child_weight=8, classifier__subsample=0.7;, score=-0.468 total time=   3.2s [repeated 23x across cluster]
# (PoolActor pid=6322) [CV 2/3; 68/150] START classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.09, classifier__gamma=0.8, classifier__lambda=0.4, classifier__max_depth=4, classifier__min_child_weight=5, classifier__subsample=0.8999999999999999 [repeated 25x across cluster]
# (PoolActor pid=6326) [CV 2/3; 64/150] END classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.16, classifier__gamma=0.8, classifier__lambda=0.9, classifier__max_depth=5, classifier__min_child_weight=8, classifier__subsample=0.7;, score=-0.463 total time=   3.4s [repeated 28x across cluster]
# (PoolActor pid=6301) [CV 3/3; 71/150] START classifier__alpha=0.30000000000000004, classifier__colsample_bytree=0.7, classifier__eta=0.01, classifier__gamma=0.9, classifier__lambda=0.9, classifier__max_depth=8, classifier__min_child_weight=8, classifier__subsample=0.7 [repeated 32x across cluster]
# (PoolActor pid=6319) [CV 1/3; 78/150] END classifier__alpha=0.0, classifier__colsample_bytree=0.6, classifier__eta=0.09999999999999999, classifier__gamma=0.7000000000000001, classifier__lambda=0.4, classifier__max_depth=9, classifier__min_child_weight=7, classifier__subsample=0.8999999999999999;, score=-0.434 total time=   4.5s [repeated 20x across cluster]
# (PoolActor pid=6325) [CV 1/3; 80/150] START classifier__alpha=0.6000000000000001, classifier__colsample_bytree=0.6, classifier__eta=0.19, classifier__gamma=0.2, classifier__lambda=0.4, classifier__max_depth=7, classifier__min_child_weight=4, classifier__subsample=0.6 [repeated 16x across cluster]
# (PoolActor pid=6298) [CV 3/3; 86/150] END classifier__alpha=0.5, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.02, classifier__gamma=0.4, classifier__lambda=0.7000000000000001, classifier__max_depth=4, classifier__min_child_weight=6, classifier__subsample=0.7;, score=-0.544 total time=   2.4s [repeated 22x across cluster]
# (PoolActor pid=6296) [CV 1/3; 86/150] START classifier__alpha=0.5, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.02, classifier__gamma=0.4, classifier__lambda=0.7000000000000001, classifier__max_depth=4, classifier__min_child_weight=6, classifier__subsample=0.7 [repeated 19x across cluster]
# (PoolActor pid=6325) [CV 3/3; 90/150] END classifier__alpha=0.9, classifier__colsample_bytree=0.6, classifier__eta=0.11, classifier__gamma=0.30000000000000004, classifier__lambda=0.4, classifier__max_depth=4, classifier__min_child_weight=5, classifier__subsample=0.8999999999999999;, score=-0.462 total time=   1.9s [repeated 22x across cluster]
# (PoolActor pid=6322) [CV 2/3; 100/150] START classifier__alpha=0.6000000000000001, classifier__colsample_bytree=0.5, classifier__eta=0.06999999999999999, classifier__gamma=0.8, classifier__lambda=0.2, classifier__max_depth=7, classifier__min_child_weight=3, classifier__subsample=0.7999999999999999 [repeated 22x across cluster]
# (PoolActor pid=6296) [CV 3/3; 96/150] END classifier__alpha=0.30000000000000004, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.04, classifier__gamma=0.7000000000000001, classifier__lambda=0.6000000000000001, classifier__max_depth=4, classifier__min_child_weight=1, classifier__subsample=0.7999999999999999;, score=-0.479 total time=   2.7s [repeated 28x across cluster]
# (PoolActor pid=6296) [CV 2/3; 107/150] START classifier__alpha=0.6000000000000001, classifier__colsample_bytree=0.5, classifier__eta=0.11, classifier__gamma=0.30000000000000004, classifier__lambda=0.9, classifier__max_depth=4, classifier__min_child_weight=6, classifier__subsample=0.7 [repeated 31x across cluster]
# (PoolActor pid=6300) [CV 2/3; 103/150] END classifier__alpha=0.5, classifier__colsample_bytree=0.6, classifier__eta=0.13, classifier__gamma=0.5, classifier__lambda=0.5, classifier__max_depth=6, classifier__min_child_weight=1, classifier__subsample=0.8999999999999999;, score=-0.456 total time=   3.1s [repeated 25x across cluster]
# (PoolActor pid=6318) [CV 1/3; 115/150] START classifier__alpha=0.6000000000000001, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.19, classifier__gamma=0.9, classifier__lambda=0.7000000000000001, classifier__max_depth=5, classifier__min_child_weight=7, classifier__subsample=0.5 [repeated 26x across cluster]
# (PoolActor pid=6321) [CV 1/3; 116/150] END classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.6, classifier__eta=0.09999999999999999, classifier__gamma=0.1, classifier__lambda=0.6000000000000001, classifier__max_depth=3, classifier__min_child_weight=8, classifier__subsample=0.5;, score=-0.443 total time=   1.7s [repeated 25x across cluster]
# (PoolActor pid=6300) [CV 3/3; 124/150] START classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.060000000000000005, classifier__gamma=0.4, classifier__lambda=0.30000000000000004, classifier__max_depth=4, classifier__min_child_weight=8, classifier__subsample=0.8999999999999999 [repeated 27x across cluster]
# (PoolActor pid=6319) [CV 1/3; 126/150] END classifier__alpha=0.9, classifier__colsample_bytree=0.7, classifier__eta=0.16, classifier__gamma=0.7000000000000001, classifier__lambda=0.8, classifier__max_depth=7, classifier__min_child_weight=6, classifier__subsample=0.7;, score=-0.438 total time=   3.9s [repeated 28x across cluster]
# (PoolActor pid=6323) [CV 2/3; 127/150] START classifier__alpha=0.9, classifier__colsample_bytree=0.8999999999999999, classifier__eta=0.09, classifier__gamma=0.2, classifier__lambda=0.30000000000000004, classifier__max_depth=7, classifier__min_child_weight=5, classifier__subsample=0.6 [repeated 26x across cluster]
# (PoolActor pid=6319) [CV 2/3; 131/150] END classifier__alpha=0.1, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.18000000000000002, classifier__gamma=0.9, classifier__lambda=0.4, classifier__max_depth=9, classifier__min_child_weight=7, classifier__subsample=0.8999999999999999;, score=-0.476 total time=   5.1s [repeated 26x across cluster]
# (PoolActor pid=6309) [CV 2/3; 141/150] START classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.7, classifier__eta=0.14, classifier__gamma=0.4, classifier__lambda=0.30000000000000004, classifier__max_depth=8, classifier__min_child_weight=7, classifier__subsample=0.7999999999999999 [repeated 23x across cluster]
# (PoolActor pid=6301) [CV 1/3; 141/150] END classifier__alpha=0.7000000000000001, classifier__colsample_bytree=0.7, classifier__eta=0.14, classifier__gamma=0.4, classifier__lambda=0.30000000000000004, classifier__max_depth=8, classifier__min_child_weight=7, classifier__subsample=0.7999999999999999;, score=-0.433 total time=   4.1s [repeated 20x across cluster]
# (PoolActor pid=6296) [CV 1/3; 150/150] START classifier__alpha=0.5, classifier__colsample_bytree=0.6, classifier__eta=0.11, classifier__gamma=0.30000000000000004, classifier__lambda=0.0, classifier__max_depth=4, classifier__min_child_weight=6, classifier__subsample=0.5 [repeated 25x across cluster]
# (PoolActor pid=6326) [CV 2/3; 144/150] END classifier__alpha=0.2, classifier__colsample_bytree=0.7999999999999999, classifier__eta=0.09999999999999999, classifier__gamma=0.4, classifier__lambda=0.5, classifier__max_depth=7, classifier__min_child_weight=4, classifier__subsample=0.6;, score=-0.457 total time=   3.6s [repeated 31x across cluster]
# (PoolActor pid=6325) [CV 2/3; 149/150] START classifier__alpha=0.2, classifier__colsample_bytree=0.6, classifier__eta=0.12, classifier__gamma=0.4, classifier__lambda=0.8, classifier__max_depth=9, classifier__min_child_weight=4, classifier__subsample=0.7 [repeated 10x across cluster]
# Fitting 3 folds for each of 150 candidates, totalling 450 fits
# (PoolActor pid=6325) [CV 2/3; 149/150] END classifier__alpha=0.2, classifier__colsample_bytree=0.6, classifier__eta=0.12, classifier__gamma=0.4, classifier__lambda=0.8, classifier__max_depth=9, classifier__min_child_weight=4, classifier__subsample=0.7;, score=-0.479 total time=   3.0s [repeated 5x across cluster]
# (PoolActor pid=8129) [CV 3/3; 1/150] START classifier__border_count=7, classifier__depth=7, classifier__l2_leaf_reg=9, classifier__learning_rate=0.01, classifier__min_data_in_leaf=3
# (PoolActor pid=8133) [CV 1/3; 3/150] START classifier__border_count=7, classifier__depth=9, classifier__l2_leaf_reg=9, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=3
# (PoolActor pid=8132) [CV 3/3; 2/150] END classifier__border_count=5, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.08, classifier__min_data_in_leaf=2;, score=-0.486 total time=   6.7s
# (PoolActor pid=8132) [CV 1/3; 8/150] START classifier__border_count=9, classifier__depth=3, classifier__l2_leaf_reg=1, classifier__learning_rate=0.12, classifier__min_data_in_leaf=7 [repeated 15x across cluster]
# (PoolActor pid=8130) [CV 1/3; 2/150] END classifier__border_count=5, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.08, classifier__min_data_in_leaf=2;, score=-0.466 total time=   6.9s
# (PoolActor pid=8132) [CV 2/3; 13/150] START classifier__border_count=4, classifier__depth=4, classifier__l2_leaf_reg=5, classifier__learning_rate=0.17, classifier__min_data_in_leaf=7 [repeated 6x across cluster]
# (PoolActor pid=8132) [CV 1/3; 8/150] END classifier__border_count=9, classifier__depth=3, classifier__l2_leaf_reg=1, classifier__learning_rate=0.12, classifier__min_data_in_leaf=7;, score=-0.463 total time=   6.5s [repeated 5x across cluster]
# (PoolActor pid=8139) [CV 2/3; 10/150] START classifier__border_count=7, classifier__depth=8, classifier__l2_leaf_reg=3, classifier__learning_rate=0.14, classifier__min_data_in_leaf=8 [repeated 8x across cluster]
# (PoolActor pid=8132) [CV 2/3; 13/150] END classifier__border_count=4, classifier__depth=4, classifier__l2_leaf_reg=5, classifier__learning_rate=0.17, classifier__min_data_in_leaf=7;, score=-0.533 total time=   6.5s [repeated 9x across cluster]
# (PoolActor pid=8126) [CV 2/3; 11/150] START classifier__border_count=4, classifier__depth=3, classifier__l2_leaf_reg=2, classifier__learning_rate=0.12, classifier__min_data_in_leaf=8 [repeated 2x across cluster]
# (PoolActor pid=8126) [CV 1/3; 6/150] END classifier__border_count=8, classifier__depth=8, classifier__l2_leaf_reg=3, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=5;, score=-0.582 total time=  25.9s [repeated 4x across cluster]
# (PoolActor pid=8132) [CV 3/3; 18/150] START classifier__border_count=2, classifier__depth=8, classifier__l2_leaf_reg=9, classifier__learning_rate=0.12, classifier__min_data_in_leaf=6 [repeated 2x across cluster]
# (PoolActor pid=8126) [CV 2/3; 11/150] END classifier__border_count=4, classifier__depth=3, classifier__l2_leaf_reg=2, classifier__learning_rate=0.12, classifier__min_data_in_leaf=8;, score=-0.500 total time=   4.3s
# (PoolActor pid=8141) [CV 2/3; 16/150] END classifier__border_count=3, classifier__depth=5, classifier__l2_leaf_reg=5, classifier__learning_rate=0.19, classifier__min_data_in_leaf=8;, score=-0.587 total time=   8.1s
# (PoolActor pid=8137) [CV 2/3; 20/150] START classifier__border_count=3, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=8 [repeated 4x across cluster]
# (PoolActor pid=8138) [CV 1/3; 10/150] END classifier__border_count=7, classifier__depth=8, classifier__l2_leaf_reg=3, classifier__learning_rate=0.14, classifier__min_data_in_leaf=8;, score=-0.569 total time=  26.4s [repeated 3x across cluster]
# (PoolActor pid=8129) [CV 2/3; 12/150] START classifier__border_count=3, classifier__depth=3, classifier__l2_leaf_reg=3, classifier__learning_rate=0.12, classifier__min_data_in_leaf=1 [repeated 13x across cluster]
# (PoolActor pid=8129) [CV 1/3; 7/150] END classifier__border_count=8, classifier__depth=8, classifier__l2_leaf_reg=9, classifier__learning_rate=0.12, classifier__min_data_in_leaf=8;, score=-0.502 total time=  26.4s [repeated 11x across cluster]
# (PoolActor pid=8140) [CV 2/3; 21/150] START classifier__border_count=3, classifier__depth=3, classifier__l2_leaf_reg=7, classifier__learning_rate=0.04, classifier__min_data_in_leaf=5 [repeated 10x across cluster]
# (PoolActor pid=8140) [CV 1/3; 16/150] END classifier__border_count=3, classifier__depth=5, classifier__l2_leaf_reg=5, classifier__learning_rate=0.19, classifier__min_data_in_leaf=8;, score=-0.524 total time=   9.8s [repeated 11x across cluster]
# (PoolActor pid=8134) [CV 2/3; 19/150] START classifier__border_count=2, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.17, classifier__min_data_in_leaf=3 [repeated 6x across cluster]
# (PoolActor pid=8134) [CV 1/3; 14/150] END classifier__border_count=5, classifier__depth=4, classifier__l2_leaf_reg=7, classifier__learning_rate=0.03, classifier__min_data_in_leaf=6;, score=-0.460 total time=   8.2s [repeated 5x across cluster]
# (PoolActor pid=8135)
# (PoolActor pid=8135) [CV 3/3; 19/150] START classifier__border_count=2, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.17, classifier__min_data_in_leaf=3 [repeated 3x across cluster]
# (PoolActor pid=8139) [CV 2/3; 26/150] END classifier__border_count=3, classifier__depth=5, classifier__l2_leaf_reg=4, classifier__learning_rate=0.13, classifier__min_data_in_leaf=7;, score=-0.550 total time=   9.3s [repeated 5x across cluster]
# (PoolActor pid=8131) [CV 3/3; 23/150] START classifier__border_count=5, classifier__depth=5, classifier__l2_leaf_reg=4, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=6 [repeated 8x across cluster]
# (PoolActor pid=8131) [CV 2/3; 18/150] END classifier__border_count=2, classifier__depth=8, classifier__l2_leaf_reg=9, classifier__learning_rate=0.12, classifier__min_data_in_leaf=6;, score=-0.584 total time=  27.3s [repeated 6x across cluster]
# (PoolActor pid=8126) [CV 2/3; 27/150] START classifier__border_count=1, classifier__depth=9, classifier__l2_leaf_reg=2, classifier__learning_rate=0.04, classifier__min_data_in_leaf=1
# (PoolActor pid=8140) [CV 1/3; 32/150] END classifier__border_count=7, classifier__depth=4, classifier__l2_leaf_reg=2, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=7;, score=-0.488 total time=   7.8s [repeated 3x across cluster]
# (PoolActor pid=8130) [CV 3/3; 28/150] START classifier__border_count=4, classifier__depth=9, classifier__l2_leaf_reg=1, classifier__learning_rate=0.16, classifier__min_data_in_leaf=2
# (PoolActor pid=8133) [CV 1/3; 19/150] END classifier__border_count=2, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.17, classifier__min_data_in_leaf=3;, score=-0.627 total time=  23.8s [repeated 7x across cluster]
# (PoolActor pid=8133) [CV 2/3; 24/150] START classifier__border_count=7, classifier__depth=5, classifier__l2_leaf_reg=3, classifier__learning_rate=0.19, classifier__min_data_in_leaf=6 [repeated 3x across cluster]
# (PoolActor pid=8131) [CV 1/3; 29/150] END classifier__border_count=9, classifier__depth=6, classifier__l2_leaf_reg=6, classifier__learning_rate=0.19, classifier__min_data_in_leaf=9;, score=-0.530 total time=   9.2s [repeated 4x across cluster]
# (PoolActor pid=8131) [CV 2/3; 34/150] START classifier__border_count=5, classifier__depth=4, classifier__l2_leaf_reg=4, classifier__learning_rate=0.05, classifier__min_data_in_leaf=2 [repeated 6x across cluster]
# (PoolActor pid=8129) [CV 3/3; 17/150] END classifier__border_count=5, classifier__depth=9, classifier__l2_leaf_reg=5, classifier__learning_rate=0.16, classifier__min_data_in_leaf=7;, score=-0.614 total time=  41.4s [repeated 8x across cluster]
# (PoolActor pid=8129) [CV 1/3; 23/150] START classifier__border_count=5, classifier__depth=5, classifier__l2_leaf_reg=4, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=6 [repeated 7x across cluster]
# (PoolActor pid=8135) [CV 1/3; 25/150] END classifier__border_count=2, classifier__depth=7, classifier__l2_leaf_reg=2, classifier__learning_rate=0.04, classifier__min_data_in_leaf=2;, score=-0.516 total time=  15.6s [repeated 4x across cluster]
# (PoolActor pid=8135) [CV 2/3; 30/150] START classifier__border_count=6, classifier__depth=3, classifier__l2_leaf_reg=8, classifier__learning_rate=0.05, classifier__min_data_in_leaf=7 [repeated 5x across cluster]
# (PoolActor pid=8135) [CV 2/3; 30/150] END classifier__border_count=6, classifier__depth=3, classifier__l2_leaf_reg=8, classifier__learning_rate=0.05, classifier__min_data_in_leaf=7;, score=-0.476 total time=   6.4s [repeated 5x across cluster]
# (PoolActor pid=8135) [CV 3/3; 35/150] START classifier__border_count=9, classifier__depth=5, classifier__l2_leaf_reg=6, classifier__learning_rate=0.16, classifier__min_data_in_leaf=6 [repeated 8x across cluster]
# (PoolActor pid=8139) [CV 1/3; 37/150] END classifier__border_count=6, classifier__depth=8, classifier__l2_leaf_reg=4, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=3;, score=-0.499 total time=  25.3s [repeated 3x across cluster]
# (PoolActor pid=8139) [CV 2/3; 42/150] START classifier__border_count=8, classifier__depth=6, classifier__l2_leaf_reg=5, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=2 [repeated 2x across cluster]
# (PoolActor pid=8132) [CV 1/3; 40/150] END classifier__border_count=3, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.16, classifier__min_data_in_leaf=7;, score=-0.556 total time=  26.8s [repeated 7x across cluster]
# (PoolActor pid=8132) [CV 2/3; 45/150] START classifier__border_count=8, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.11, classifier__min_data_in_leaf=1 [repeated 7x across cluster]
# (PoolActor pid=8126) [CV 3/3; 32/150] END classifier__border_count=7, classifier__depth=4, classifier__l2_leaf_reg=2, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=7;, score=-0.546 total time=   7.6s [repeated 5x across cluster]
# (PoolActor pid=8126) [CV 1/3; 38/150] START classifier__border_count=1, classifier__depth=6, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=4 [repeated 4x across cluster]
# (PoolActor pid=8139) [CV 3/3; 47/150] END classifier__border_count=8, classifier__depth=3, classifier__l2_leaf_reg=8, classifier__learning_rate=0.19, classifier__min_data_in_leaf=1;, score=-0.498 total time=   6.4s [repeated 4x across cluster]
# (PoolActor pid=8133) [CV 3/3; 45/150] START classifier__border_count=8, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.11, classifier__min_data_in_leaf=1 [repeated 4x across cluster]
# (PoolActor pid=8126) [CV 1/3; 38/150] END classifier__border_count=1, classifier__depth=6, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=4;, score=-0.616 total time=  13.0s [repeated 6x across cluster]
# (PoolActor pid=8126) [CV 2/3; 43/150] START classifier__border_count=1, classifier__depth=5, classifier__l2_leaf_reg=7, classifier__learning_rate=0.04, classifier__min_data_in_leaf=2 [repeated 4x across cluster]
# (PoolActor pid=8141) [CV 2/3; 48/150] END classifier__border_count=3, classifier__depth=3, classifier__l2_leaf_reg=9, classifier__learning_rate=0.02, classifier__min_data_in_leaf=6;, score=-0.485 total time=   5.7s [repeated 6x across cluster]
# (PoolActor pid=8138) [CV 3/3; 52/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=6, classifier__learning_rate=0.03, classifier__min_data_in_leaf=7 [repeated 6x across cluster]
# (PoolActor pid=8133) [CV 3/3; 45/150] END classifier__border_count=8, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.11, classifier__min_data_in_leaf=1;, score=-0.548 total time=  24.0s [repeated 7x across cluster]
# (PoolActor pid=8133) [CV 1/3; 51/150] START classifier__border_count=8, classifier__depth=9, classifier__l2_leaf_reg=4, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=9 [repeated 7x across cluster]
# (PoolActor pid=8141) [CV 3/3; 53/150] END classifier__border_count=9, classifier__depth=6, classifier__l2_leaf_reg=3, classifier__learning_rate=0.19, classifier__min_data_in_leaf=1;, score=-0.624 total time=   9.9s [repeated 6x across cluster]
# (PoolActor pid=8132) [CV 1/3; 56/150] START classifier__border_count=2, classifier__depth=4, classifier__l2_leaf_reg=2, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=3 [repeated 5x across cluster]
# (PoolActor pid=8129) [CV 3/3; 33/150] END classifier__border_count=6, classifier__depth=8, classifier__l2_leaf_reg=5, classifier__learning_rate=0.11, classifier__min_data_in_leaf=3;, score=-0.573 total time=  24.2s [repeated 7x across cluster]
# (PoolActor pid=8129) [CV 1/3; 39/150] START classifier__border_count=7, classifier__depth=7, classifier__l2_leaf_reg=8, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=8 [repeated 9x across cluster]
# (PoolActor pid=8137) [CV 3/3; 57/150] END classifier__border_count=9, classifier__depth=4, classifier__l2_leaf_reg=6, classifier__learning_rate=0.03, classifier__min_data_in_leaf=6;, score=-0.474 total time=   7.3s [repeated 8x across cluster]
# (PoolActor pid=8135) [CV 3/3; 51/150] START classifier__border_count=8, classifier__depth=9, classifier__l2_leaf_reg=4, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=9 [repeated 7x across cluster]
# (PoolActor pid=8128) [CV 2/3; 33/150] END classifier__border_count=6, classifier__depth=8, classifier__l2_leaf_reg=5, classifier__learning_rate=0.11, classifier__min_data_in_leaf=3;, score=-0.564 total time=  25.0s [repeated 3x across cluster]
# (PoolActor pid=8139) [CV 3/3; 63/150] START classifier__border_count=9, classifier__depth=4, classifier__l2_leaf_reg=9, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=4 [repeated 5x across cluster]
# (PoolActor pid=8136) [CV 3/3; 62/150] END classifier__border_count=6, classifier__depth=6, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=6;, score=-0.539 total time=  11.8s [repeated 7x across cluster]
# (PoolActor pid=8129) [CV 2/3; 44/150] START classifier__border_count=5, classifier__depth=6, classifier__l2_leaf_reg=8, classifier__learning_rate=0.08, classifier__min_data_in_leaf=9 [repeated 3x across cluster]
# (PoolActor pid=8129) [CV 2/3; 44/150] END classifier__border_count=5, classifier__depth=6, classifier__l2_leaf_reg=8, classifier__learning_rate=0.08, classifier__min_data_in_leaf=9;, score=-0.506 total time=   9.8s [repeated 6x across cluster]
# (PoolActor pid=8129) [CV 3/3; 49/150] START classifier__border_count=4, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=9 [repeated 7x across cluster]
# (PoolActor pid=8129) [CV 3/3; 49/150] END classifier__border_count=4, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=9;, score=-0.546 total time=   6.8s [repeated 4x across cluster]
# (PoolActor pid=8129) [CV 1/3; 55/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=8, classifier__learning_rate=0.12, classifier__min_data_in_leaf=3 [repeated 7x across cluster]
# (PoolActor pid=8128) [CV 2/3; 49/150] END classifier__border_count=4, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=9;, score=-0.545 total time=   7.3s [repeated 9x across cluster]
# (PoolActor pid=8128) [CV 3/3; 54/150] START classifier__border_count=3, classifier__depth=7, classifier__l2_leaf_reg=2, classifier__learning_rate=0.13, classifier__min_data_in_leaf=4 [repeated 7x across cluster]
# (PoolActor pid=8141) [CV 2/3; 64/150] END classifier__border_count=4, classifier__depth=3, classifier__l2_leaf_reg=1, classifier__learning_rate=0.11, classifier__min_data_in_leaf=2;, score=-0.501 total time=   6.1s [repeated 7x across cluster]
# (PoolActor pid=8138) [CV 1/3; 74/150] START classifier__border_count=4, classifier__depth=7, classifier__l2_leaf_reg=9, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=2 [repeated 8x across cluster]
# (PoolActor pid=8135) [CV 1/3; 57/150] END classifier__border_count=9, classifier__depth=4, classifier__l2_leaf_reg=6, classifier__learning_rate=0.03, classifier__min_data_in_leaf=6;, score=-0.453 total time=   7.3s [repeated 7x across cluster]
# (PoolActor pid=8135) [CV 2/3; 62/150] START classifier__border_count=6, classifier__depth=6, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=6 [repeated 8x across cluster]
# (PoolActor pid=8132) [CV 1/3; 72/150] END classifier__border_count=9, classifier__depth=5, classifier__l2_leaf_reg=5, classifier__learning_rate=0.02, classifier__min_data_in_leaf=1;, score=-0.454 total time=   8.8s [repeated 8x across cluster]
# (PoolActor pid=8132) [CV 2/3; 77/150] START classifier__border_count=6, classifier__depth=3, classifier__l2_leaf_reg=7, classifier__learning_rate=0.12, classifier__min_data_in_leaf=9 [repeated 10x across cluster]
# (PoolActor pid=8129) [CV 1/3; 71/150] END classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=1, classifier__learning_rate=0.13, classifier__min_data_in_leaf=6;, score=-0.467 total time=   6.8s [repeated 3x across cluster]
# (PoolActor pid=8129) [CV 2/3; 76/150] START classifier__border_count=9, classifier__depth=5, classifier__l2_leaf_reg=2, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=5 [repeated 3x across cluster]
# (PoolActor pid=8127) [CV 2/3; 54/150] END classifier__border_count=3, classifier__depth=7, classifier__l2_leaf_reg=2, classifier__learning_rate=0.13, classifier__min_data_in_leaf=4;, score=-0.650 total time=  15.2s [repeated 11x across cluster]
# (PoolActor pid=8127) [CV 3/3; 59/150] START classifier__border_count=3, classifier__depth=9, classifier__l2_leaf_reg=8, classifier__learning_rate=0.05, classifier__min_data_in_leaf=5 [repeated 10x across cluster]
# (PoolActor pid=8139) [CV 3/3; 79/150] END classifier__border_count=5, classifier__depth=5, classifier__l2_leaf_reg=6, classifier__learning_rate=0.12, classifier__min_data_in_leaf=8;, score=-0.522 total time=   9.5s [repeated 6x across cluster]
# (PoolActor pid=8139) [CV 1/3; 85/150] START classifier__border_count=7, classifier__depth=8, classifier__l2_leaf_reg=6, classifier__learning_rate=0.12, classifier__min_data_in_leaf=2 [repeated 7x across cluster]
# (PoolActor pid=8134) [CV 1/3; 78/150] END classifier__border_count=5, classifier__depth=8, classifier__l2_leaf_reg=8, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=3;, score=-0.475 total time=  28.9s [repeated 7x across cluster]
# (PoolActor pid=8134) [CV 2/3; 83/150] START classifier__border_count=9, classifier__depth=3, classifier__l2_leaf_reg=9, classifier__learning_rate=0.08, classifier__min_data_in_leaf=3 [repeated 7x across cluster]
# (PoolActor pid=8134) [CV 2/3; 83/150] END classifier__border_count=9, classifier__depth=3, classifier__l2_leaf_reg=9, classifier__learning_rate=0.08, classifier__min_data_in_leaf=3;, score=-0.474 total time=   7.4s [repeated 6x across cluster]
# (PoolActor pid=8134) [CV 3/3; 88/150] START classifier__border_count=5, classifier__depth=9, classifier__l2_leaf_reg=7, classifier__learning_rate=0.12, classifier__min_data_in_leaf=4 [repeated 4x across cluster]
# (PoolActor pid=8128) [CV 3/3; 70/150] END classifier__border_count=9, classifier__depth=7, classifier__l2_leaf_reg=6, classifier__learning_rate=0.17, classifier__min_data_in_leaf=5;, score=-0.585 total time=  19.2s [repeated 2x across cluster]
# (PoolActor pid=8128) [CV 1/3; 76/150] START classifier__border_count=9, classifier__depth=5, classifier__l2_leaf_reg=2, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=5
# (PoolActor pid=8141) [CV 2/3; 80/150] START classifier__border_count=4, classifier__depth=3, classifier__l2_leaf_reg=4, classifier__learning_rate=0.02, classifier__min_data_in_leaf=5
# (PoolActor pid=8137) [CV 2/3; 84/150] END classifier__border_count=7, classifier__depth=8, classifier__l2_leaf_reg=4, classifier__learning_rate=0.17, classifier__min_data_in_leaf=9;, score=-0.617 total time=  30.2s [repeated 2x across cluster]
# (PoolActor pid=8140) [CV 3/3; 90/150] START classifier__border_count=5, classifier__depth=6, classifier__l2_leaf_reg=6, classifier__learning_rate=0.12, classifier__min_data_in_leaf=4 [repeated 7x across cluster]
# (PoolActor pid=8126) [CV 2/3; 75/150] END classifier__border_count=4, classifier__depth=9, classifier__l2_leaf_reg=3, classifier__learning_rate=0.17, classifier__min_data_in_leaf=5;, score=-0.655 total time=  43.1s [repeated 7x across cluster]
# (PoolActor pid=8126) [CV 3/3; 80/150] START classifier__border_count=4, classifier__depth=3, classifier__l2_leaf_reg=4, classifier__learning_rate=0.02, classifier__min_data_in_leaf=5 [repeated 4x across cluster]
# (PoolActor pid=8138) [CV 1/3; 90/150] END classifier__border_count=5, classifier__depth=6, classifier__l2_leaf_reg=6, classifier__learning_rate=0.12, classifier__min_data_in_leaf=4;, score=-0.507 total time=  11.4s [repeated 8x across cluster]
# (PoolActor pid=8138) [CV 2/3; 95/150] START classifier__border_count=2, classifier__depth=3, classifier__l2_leaf_reg=6, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=6 [repeated 6x across cluster]
# (PoolActor pid=8127) [CV 1/3; 65/150] END classifier__border_count=1, classifier__depth=4, classifier__l2_leaf_reg=3, classifier__learning_rate=0.05, classifier__min_data_in_leaf=5;, score=-0.529 total time=   6.7s [repeated 4x across cluster]
# (PoolActor pid=8132) [CV 2/3; 93/150] START classifier__border_count=8, classifier__depth=6, classifier__l2_leaf_reg=9, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=9 [repeated 7x across cluster]
# (PoolActor pid=8140) [CV 1/3; 96/150] END classifier__border_count=4, classifier__depth=5, classifier__l2_leaf_reg=2, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=6;, score=-0.549 total time=   9.3s [repeated 4x across cluster]
# (PoolActor pid=8137) [CV 1/3; 95/150] START classifier__border_count=2, classifier__depth=3, classifier__l2_leaf_reg=6, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=6
# (PoolActor pid=8133) [CV 3/3; 93/150] START classifier__border_count=8, classifier__depth=6, classifier__l2_leaf_reg=9, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=9
# (PoolActor pid=8132) [CV 2/3; 93/150] END classifier__border_count=8, classifier__depth=6, classifier__l2_leaf_reg=9, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=9;, score=-0.485 total time=  10.8s [repeated 5x across cluster]
# (PoolActor pid=8137) [CV 2/3; 100/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=4, classifier__learning_rate=0.19, classifier__min_data_in_leaf=5 [repeated 7x across cluster]
# (PoolActor pid=8141) [CV 1/3; 91/150] END classifier__border_count=3, classifier__depth=3, classifier__l2_leaf_reg=8, classifier__learning_rate=0.05, classifier__min_data_in_leaf=5;, score=-0.468 total time=   6.3s [repeated 4x across cluster]
# (PoolActor pid=8129) [CV 1/3; 103/150] START classifier__border_count=2, classifier__depth=6, classifier__l2_leaf_reg=5, classifier__learning_rate=0.01, classifier__min_data_in_leaf=9 [repeated 3x across cluster]
# (PoolActor pid=8141) [CV 2/3; 96/150] END classifier__border_count=4, classifier__depth=5, classifier__l2_leaf_reg=2, classifier__learning_rate=0.18000000000000002, classifier__min_data_in_leaf=6;, score=-0.603 total time=   9.4s [repeated 6x across cluster]
# (PoolActor pid=8141) [CV 3/3; 101/150] START classifier__border_count=6, classifier__depth=7, classifier__l2_leaf_reg=6, classifier__learning_rate=0.11, classifier__min_data_in_leaf=5 [repeated 4x across cluster]
# (PoolActor pid=8129) [CV 1/3; 103/150] END classifier__border_count=2, classifier__depth=6, classifier__l2_leaf_reg=5, classifier__learning_rate=0.01, classifier__min_data_in_leaf=9;, score=-0.480 total time=  12.4s [repeated 6x across cluster]
# (PoolActor pid=8138) [CV 1/3; 106/150] START classifier__border_count=9, classifier__depth=7, classifier__l2_leaf_reg=2, classifier__learning_rate=0.01, classifier__min_data_in_leaf=1 [repeated 5x across cluster]
# (PoolActor pid=8126) [CV 1/3; 86/150] END classifier__border_count=2, classifier__depth=9, classifier__l2_leaf_reg=8, classifier__learning_rate=0.03, classifier__min_data_in_leaf=2;, score=-0.495 total time=  44.0s [repeated 5x across cluster]
# (PoolActor pid=8133) [CV 2/3; 104/150] START classifier__border_count=6, classifier__depth=6, classifier__l2_leaf_reg=9, classifier__learning_rate=0.11, classifier__min_data_in_leaf=2 [repeated 6x across cluster]
# (PoolActor pid=8141) [CV 3/3; 101/150] END classifier__border_count=6, classifier__depth=7, classifier__l2_leaf_reg=6, classifier__learning_rate=0.11, classifier__min_data_in_leaf=5;, score=-0.554 total time=  16.8s [repeated 6x across cluster]
# (PoolActor pid=8141) [CV 1/3; 107/150] START classifier__border_count=1, classifier__depth=5, classifier__l2_leaf_reg=8, classifier__learning_rate=0.04, classifier__min_data_in_leaf=3 [repeated 7x across cluster]
# (PoolActor pid=8139) [CV 2/3; 106/150] END classifier__border_count=9, classifier__depth=7, classifier__l2_leaf_reg=2, classifier__learning_rate=0.01, classifier__min_data_in_leaf=1;, score=-0.472 total time=  17.0s [repeated 8x across cluster]
# (PoolActor pid=8139) [CV 3/3; 111/150] START classifier__border_count=2, classifier__depth=8, classifier__l2_leaf_reg=6, classifier__learning_rate=0.17, classifier__min_data_in_leaf=7 [repeated 8x across cluster]
# (PoolActor pid=8128) [CV 2/3; 97/150] END classifier__border_count=3, classifier__depth=7, classifier__l2_leaf_reg=9, classifier__learning_rate=0.09, classifier__min_data_in_leaf=1;, score=-0.535 total time=  16.0s [repeated 8x across cluster]
# (PoolActor pid=8128) [CV 3/3; 102/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=7, classifier__learning_rate=0.11, classifier__min_data_in_leaf=7 [repeated 8x across cluster]
# (PoolActor pid=8128) [CV 3/3; 102/150] END classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=7, classifier__learning_rate=0.11, classifier__min_data_in_leaf=7;, score=-0.483 total time=   5.2s [repeated 5x across cluster]
# (PoolActor pid=8128) [CV 1/3; 108/150] START classifier__border_count=4, classifier__depth=5, classifier__l2_leaf_reg=9, classifier__learning_rate=0.17, classifier__min_data_in_leaf=1 [repeated 6x across cluster]
# (PoolActor pid=8136) [CV 1/3; 116/150] END classifier__border_count=6, classifier__depth=4, classifier__l2_leaf_reg=4, classifier__learning_rate=0.12, classifier__min_data_in_leaf=7;, score=-0.467 total time=   7.9s [repeated 3x across cluster]
# (PoolActor pid=8134) [CV 2/3; 115/150] START classifier__border_count=6, classifier__depth=9, classifier__l2_leaf_reg=6, classifier__learning_rate=0.05, classifier__min_data_in_leaf=1
# (PoolActor pid=8135) [CV 3/3; 115/150] START classifier__border_count=6, classifier__depth=9, classifier__l2_leaf_reg=6, classifier__learning_rate=0.05, classifier__min_data_in_leaf=1
# (PoolActor pid=8126) [CV 2/3; 107/150] END classifier__border_count=1, classifier__depth=5, classifier__l2_leaf_reg=8, classifier__learning_rate=0.04, classifier__min_data_in_leaf=3;, score=-0.532 total time=  11.8s [repeated 4x across cluster]
# (PoolActor pid=8137) [CV 2/3; 116/150] START classifier__border_count=6, classifier__depth=4, classifier__l2_leaf_reg=4, classifier__learning_rate=0.12, classifier__min_data_in_leaf=7 [repeated 5x across cluster]
# (PoolActor pid=8133) [CV 3/3; 109/150] END classifier__border_count=7, classifier__depth=8, classifier__l2_leaf_reg=2, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=6;, score=-0.545 total time=  28.9s [repeated 3x across cluster]
# (PoolActor pid=8140) [CV 2/3; 117/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=6 [repeated 3x across cluster]
# (PoolActor pid=8141) [CV 2/3; 112/150] END classifier__border_count=4, classifier__depth=8, classifier__l2_leaf_reg=2, classifier__learning_rate=0.02, classifier__min_data_in_leaf=4;, score=-0.489 total time=  29.9s [repeated 5x across cluster]
# (PoolActor pid=8141) [CV 3/3; 117/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=6 [repeated 5x across cluster]
# (PoolActor pid=8141) [CV 3/3; 117/150] END classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=4, classifier__learning_rate=0.09999999999999999, classifier__min_data_in_leaf=6;, score=-0.485 total time=   6.3s [repeated 8x across cluster]
# (PoolActor pid=8141) [CV 1/3; 123/150] START classifier__border_count=2, classifier__depth=6, classifier__l2_leaf_reg=9, classifier__learning_rate=0.17, classifier__min_data_in_leaf=1 [repeated 6x across cluster]
# (PoolActor pid=8129) [CV 1/3; 119/150] END classifier__border_count=1, classifier__depth=7, classifier__l2_leaf_reg=9, classifier__learning_rate=0.11, classifier__min_data_in_leaf=8;, score=-0.625 total time=  24.7s [repeated 2x across cluster]
# (PoolActor pid=8129) [CV 2/3; 124/150] START classifier__border_count=7, classifier__depth=7, classifier__l2_leaf_reg=7, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=1 [repeated 2x across cluster]
# (PoolActor pid=8126) [CV 3/3; 112/150] END classifier__border_count=4, classifier__depth=8, classifier__l2_leaf_reg=2, classifier__learning_rate=0.02, classifier__min_data_in_leaf=4;, score=-0.492 total time=  30.9s
# (PoolActor pid=8126) [CV 1/3; 118/150] START classifier__border_count=8, classifier__depth=8, classifier__l2_leaf_reg=7, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=8
# (PoolActor pid=8141) [CV 1/3; 123/150] END classifier__border_count=2, classifier__depth=6, classifier__l2_leaf_reg=9, classifier__learning_rate=0.17, classifier__min_data_in_leaf=1;, score=-0.566 total time=  13.0s
# (PoolActor pid=8136) [CV 3/3; 126/150] START classifier__border_count=7, classifier__depth=6, classifier__l2_leaf_reg=4, classifier__learning_rate=0.12, classifier__min_data_in_leaf=5
# (PoolActor pid=8138) [CV 1/3; 122/150] END classifier__border_count=8, classifier__depth=7, classifier__l2_leaf_reg=7, classifier__learning_rate=0.05, classifier__min_data_in_leaf=4;, score=-0.461 total time=  18.8s [repeated 4x across cluster]
# (PoolActor pid=8139) [CV 3/3; 127/150] START classifier__border_count=6, classifier__depth=5, classifier__l2_leaf_reg=3, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=9 [repeated 4x across cluster]
# (PoolActor pid=8137) [CV 1/3; 127/150] END classifier__border_count=6, classifier__depth=5, classifier__l2_leaf_reg=3, classifier__learning_rate=0.06999999999999999, classifier__min_data_in_leaf=9;, score=-0.464 total time=  10.0s [repeated 6x across cluster]
# (PoolActor pid=8135) [CV 1/3; 121/150] START classifier__border_count=7, classifier__depth=3, classifier__l2_leaf_reg=8, classifier__learning_rate=0.060000000000000005, classifier__min_data_in_leaf=4 [repeated 6x across cluster]
# (PoolActor pid=8132) [CV 3/3; 114/150] END classifier__border_count=1, classifier__depth=8, classifier__l2_leaf_reg=6, classifier__learning_rate=0.05, classifier__min_data_in_leaf=5;, score=-0.609 total time=  35.6s [repeated 10x across cluster]
# (PoolActor pid=8132) [CV 1/3; 120/150] START classifier__border_count=1, classifier__depth=4, classifier__l2_leaf_reg=7, classifier__learning_rate=0.11, classifier__min_data_in_leaf=5 [repeated 8x across cluster]
# (PoolActor pid=8129) [CV 3/3; 129/150] END classifier__border_count=7, classifier__depth=5, classifier__l2_leaf_reg=8, classifier__learning_rate=0.19, classifier__min_data_in_leaf=9;, score=-0.541 total time=  10.3s [repeated 2x across cluster]
# (PoolActor pid=8139) [CV 1/3; 133/150] START classifier__border_count=3, classifier__depth=6, classifier__l2_leaf_reg=6, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=5 [repeated 3x across cluster]
# (PoolActor pid=8128) [CV 1/3; 124/150] END classifier__border_count=7, classifier__depth=7, classifier__l2_leaf_reg=7, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=1;, score=-0.516 total time=  18.7s [repeated 6x across cluster]
# (PoolActor pid=8128) [CV 2/3; 129/150] START classifier__border_count=7, classifier__depth=5, classifier__l2_leaf_reg=8, classifier__learning_rate=0.19, classifier__min_data_in_leaf=9 [repeated 9x across cluster]
# (PoolActor pid=8127) [CV 1/3; 97/150] END classifier__border_count=3, classifier__depth=7, classifier__l2_leaf_reg=9, classifier__learning_rate=0.09, classifier__min_data_in_leaf=1;, score=-0.492 total time=  18.2s [repeated 4x across cluster]
# (PoolActor pid=8130) [CV 1/3; 130/150] START classifier__border_count=5, classifier__depth=7, classifier__l2_leaf_reg=7, classifier__learning_rate=0.05, classifier__min_data_in_leaf=9 [repeated 2x across cluster]
# (PoolActor pid=8141) [CV 3/3; 133/150] END classifier__border_count=3, classifier__depth=6, classifier__l2_leaf_reg=6, classifier__learning_rate=0.15000000000000002, classifier__min_data_in_leaf=5;, score=-0.592 total time=  13.4s [repeated 7x across cluster]
# (PoolActor pid=8141) [CV 1/3; 139/150] START classifier__border_count=3, classifier__depth=9, classifier__l2_leaf_reg=4, classifier__learning_rate=0.11, classifier__min_data_in_leaf=5 [repeated 9x across cluster]
# ...
# (PoolActor pid=24468) [CV 3/3; 99/150] END classifier__leaf_size=5, classifier__n_neighbors=24, classifier__p=6, classifier__weights=distance;, score=-1.032 total time=  14.4s [repeated 4x across cluster]
# (PoolActor pid=24471) [CV 2/3; 95/150] START classifier__leaf_size=9, classifier__n_neighbors=17, classifier__p=9, classifier__weights=distance [repeated 5x across cluster]
# (PoolActor pid=24459) [CV 2/3; 91/150] END classifier__leaf_size=7, classifier__n_neighbors=24, classifier__p=6, classifier__weights=uniform;, score=-1.065 total time=  14.3s
# (PoolActor pid=24473) [CV 2/3; 90/150] END classifier__leaf_size=7, classifier__n_neighbors=18, classifier__p=9, classifier__weights=distance;, score=-1.181 total time=  15.0s [repeated 2x across cluster]
# (PoolActor pid=24465) [CV 3/3; 98/150] END classifier__leaf_size=5, classifier__n_neighbors=21, classifier__p=4, classifier__weights=uniform;, score=-1.062 total time=  15.3s
# (PoolActor pid=24465) [CV 1/3; 104/150] START classifier__leaf_size=6, classifier__n_neighbors=24, classifier__p=8, classifier__weights=uniform
# (PoolActor pid=24470) [CV 1/3; 95/150] START classifier__leaf_size=9, classifier__n_neighbors=17, classifier__p=9, classifier__weights=distance [repeated 3x across cluster]
# (PoolActor pid=24474) [CV 3/3; 101/150] END classifier__leaf_size=6, classifier__n_neighbors=22, classifier__p=8, classifier__weights=distance;, score=-1.034 total time=  14.0s [repeated 2x across cluster]
# (PoolActor pid=24469) [CV 2/3; 105/150] END classifier__leaf_size=6, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform;, score=-0.984 total time=  14.2s [repeated 5x across cluster]
# (PoolActor pid=24460) [CV 3/3; 107/150] START classifier__leaf_size=4, classifier__n_neighbors=20, classifier__p=8, classifier__weights=distance [repeated 8x across cluster]
# (PoolActor pid=24459) [CV 1/3; 102/150] START classifier__leaf_size=8, classifier__n_neighbors=16, classifier__p=7, classifier__weights=uniform
# (PoolActor pid=24471) [CV 2/3; 95/150] END classifier__leaf_size=9, classifier__n_neighbors=17, classifier__p=9, classifier__weights=distance;, score=-1.264 total time=  13.9s [repeated 8x across cluster]
# (PoolActor pid=24468) [CV 1/3; 105/150] END classifier__leaf_size=6, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform;, score=-0.902 total time=  14.3s [repeated 2x across cluster]
# (PoolActor pid=24471) [CV 3/3; 100/150] START classifier__leaf_size=4, classifier__n_neighbors=27, classifier__p=2, classifier__weights=distance [repeated 3x across cluster]
# (PoolActor pid=24466) [CV 2/3; 104/150] START classifier__leaf_size=6, classifier__n_neighbors=24, classifier__p=8, classifier__weights=uniform [repeated 2x across cluster]
# (PoolActor pid=24473) [CV 3/3; 95/150] END classifier__leaf_size=9, classifier__n_neighbors=17, classifier__p=9, classifier__weights=distance;, score=-1.267 total time=  15.1s [repeated 3x across cluster]
# (PoolActor pid=24461) [CV 2/3; 113/150] END classifier__leaf_size=9, classifier__n_neighbors=25, classifier__p=2, classifier__weights=uniform;, score=-0.983 total time=   0.3s [repeated 6x across cluster]
# (PoolActor pid=24464) [CV 2/3; 114/150] START classifier__leaf_size=6, classifier__n_neighbors=15, classifier__p=2, classifier__weights=distance [repeated 4x across cluster]
# (PoolActor pid=24472) [CV 3/3; 106/150] START classifier__leaf_size=3, classifier__n_neighbors=20, classifier__p=8, classifier__weights=uniform [repeated 10x across cluster]
# (PoolActor pid=24462) [CV 2/3; 108/150] END classifier__leaf_size=4, classifier__n_neighbors=20, classifier__p=9, classifier__weights=distance;, score=-1.127 total time=  12.9s [repeated 12x across cluster]
# (PoolActor pid=24471) [CV 1/3; 106/150] END classifier__leaf_size=3, classifier__n_neighbors=20, classifier__p=8, classifier__weights=uniform;, score=-1.191 total time=  13.7s [repeated 4x across cluster]
# (PoolActor pid=24459) [CV 2/3; 107/150] START classifier__leaf_size=4, classifier__n_neighbors=20, classifier__p=8, classifier__weights=distance [repeated 2x across cluster]
# (PoolActor pid=24471) [CV 2/3; 111/150] START classifier__leaf_size=5, classifier__n_neighbors=17, classifier__p=3, classifier__weights=uniform [repeated 10x across cluster]
# (PoolActor pid=24473) [CV 1/3; 101/150] END classifier__leaf_size=6, classifier__n_neighbors=22, classifier__p=8, classifier__weights=distance;, score=-1.143 total time=  13.3s
# (PoolActor pid=24470) [CV 3/3; 105/150] END classifier__leaf_size=6, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform;, score=-0.929 total time=  13.8s [repeated 4x across cluster]
# (PoolActor pid=24470) [CV 1/3; 111/150] START classifier__leaf_size=5, classifier__n_neighbors=17, classifier__p=3, classifier__weights=uniform [repeated 5x across cluster]
# (PoolActor pid=24474) [CV 1/3; 123/150] START classifier__leaf_size=1, classifier__n_neighbors=16, classifier__p=3, classifier__weights=distance
# (PoolActor pid=24464) [CV 3/3; 119/150] END classifier__leaf_size=2, classifier__n_neighbors=25, classifier__p=4, classifier__weights=uniform;, score=-0.981 total time=  15.7s [repeated 9x across cluster]
# (PoolActor pid=24464) [CV 1/3; 125/150] START classifier__leaf_size=7, classifier__n_neighbors=20, classifier__p=1, classifier__weights=uniform [repeated 5x across cluster]
# (PoolActor pid=24459) [CV 2/3; 107/150] END classifier__leaf_size=4, classifier__n_neighbors=20, classifier__p=8, classifier__weights=distance;, score=-1.155 total time=  15.6s
# (PoolActor pid=24462) [CV 2/3; 124/150] START classifier__leaf_size=7, classifier__n_neighbors=26, classifier__p=8, classifier__weights=distance [repeated 4x across cluster]
# (PoolActor pid=24473) [CV 2/3; 106/150] END classifier__leaf_size=3, classifier__n_neighbors=20, classifier__p=8, classifier__weights=uniform;, score=-1.160 total time=  13.3s [repeated 7x across cluster]
# (PoolActor pid=24473) [CV 3/3; 111/150] START classifier__leaf_size=5, classifier__n_neighbors=17, classifier__p=3, classifier__weights=uniform [repeated 5x across cluster]
# (PoolActor pid=24474) [CV 1/3; 123/150] END classifier__leaf_size=1, classifier__n_neighbors=16, classifier__p=3, classifier__weights=distance;, score=-1.261 total time=  14.3s
# (PoolActor pid=24474) [CV 2/3; 128/150] START classifier__leaf_size=7, classifier__n_neighbors=28, classifier__p=5, classifier__weights=distance
# (PoolActor pid=24469) [CV 2/3; 121/150] END classifier__leaf_size=1, classifier__n_neighbors=26, classifier__p=6, classifier__weights=uniform;, score=-1.039 total time=  13.6s [repeated 4x across cluster]
# (PoolActor pid=24465) [CV 3/3; 130/150] START classifier__leaf_size=9, classifier__n_neighbors=17, classifier__p=5, classifier__weights=uniform [repeated 5x across cluster]
# (PoolActor pid=24462) [CV 2/3; 124/150] END classifier__leaf_size=7, classifier__n_neighbors=26, classifier__p=8, classifier__weights=distance;, score=-1.033 total time=  13.7s [repeated 4x across cluster]
# (PoolActor pid=24468) [CV 3/3; 131/150] START classifier__leaf_size=7, classifier__n_neighbors=23, classifier__p=7, classifier__weights=distance [repeated 3x across cluster]
# (PoolActor pid=24471) [CV 3/3; 116/150] END classifier__leaf_size=4, classifier__n_neighbors=22, classifier__p=4, classifier__weights=uniform;, score=-1.049 total time=  13.4s [repeated 6x across cluster]
# (PoolActor pid=24471) [CV 1/3; 122/150] START classifier__leaf_size=1, classifier__n_neighbors=20, classifier__p=4, classifier__weights=uniform [repeated 8x across cluster]
# (PoolActor pid=24464) [CV 2/3; 130/150] END classifier__leaf_size=9, classifier__n_neighbors=17, classifier__p=5, classifier__weights=uniform;, score=-1.225 total time=  14.2s [repeated 3x across cluster]
# (PoolActor pid=24473) [CV 2/3; 122/150] START classifier__leaf_size=1, classifier__n_neighbors=20, classifier__p=4, classifier__weights=uniform [repeated 2x across cluster]
# (PoolActor pid=24464) [CV 3/3; 135/150] START classifier__leaf_size=7, classifier__n_neighbors=16, classifier__p=7, classifier__weights=distance
# (PoolActor pid=24469) [CV 1/3; 132/150] END classifier__leaf_size=3, classifier__n_neighbors=24, classifier__p=2, classifier__weights=distance;, score=-1.037 total time=   0.5s
# (PoolActor pid=24460) [CV 1/3; 129/150] END classifier__leaf_size=3, classifier__n_neighbors=23, classifier__p=5, classifier__weights=uniform;, score=-1.119 total time=  15.0s [repeated 6x across cluster]
# (PoolActor pid=24460) [CV 2/3; 134/150] START classifier__leaf_size=5, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform [repeated 3x across cluster]
# (PoolActor pid=24459) [CV 2/3; 123/150] START classifier__leaf_size=1, classifier__n_neighbors=16, classifier__p=3, classifier__weights=distance [repeated 8x across cluster]
# (PoolActor pid=24468) [CV 3/3; 131/150] END classifier__leaf_size=7, classifier__n_neighbors=23, classifier__p=7, classifier__weights=distance;, score=-1.048 total time=  15.1s [repeated 5x across cluster]
# (PoolActor pid=24473) [CV 2/3; 122/150] END classifier__leaf_size=1, classifier__n_neighbors=20, classifier__p=4, classifier__weights=uniform;, score=-1.145 total time=  14.2s [repeated 5x across cluster]
# (PoolActor pid=24474) [CV 1/3; 139/150] START classifier__leaf_size=5, classifier__n_neighbors=19, classifier__p=5, classifier__weights=uniform
# (PoolActor pid=24473) [CV 3/3; 127/150] START classifier__leaf_size=9, classifier__n_neighbors=25, classifier__p=5, classifier__weights=distance [repeated 5x across cluster]
# (PoolActor pid=24464) [CV 3/3; 135/150] END classifier__leaf_size=7, classifier__n_neighbors=16, classifier__p=7, classifier__weights=distance;, score=-1.320 total time=  15.0s
# (PoolActor pid=24464) [CV 1/3; 141/150] START classifier__leaf_size=7, classifier__n_neighbors=29, classifier__p=7, classifier__weights=uniform
# (PoolActor pid=24461) [CV 3/3; 134/150] END classifier__leaf_size=5, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform;, score=-0.929 total time=  14.2s [repeated 2x across cluster]
# (PoolActor pid=24463) [CV 3/3; 140/150] START classifier__leaf_size=6, classifier__n_neighbors=24, classifier__p=4, classifier__weights=distance [repeated 4x across cluster]
# (PoolActor pid=24468) [CV 1/3; 137/150] END classifier__leaf_size=6, classifier__n_neighbors=22, classifier__p=7, classifier__weights=distance;, score=-1.130 total time=  14.9s [repeated 9x across cluster]
# (PoolActor pid=24472) [CV 3/3; 138/150] START classifier__leaf_size=1, classifier__n_neighbors=22, classifier__p=8, classifier__weights=uniform [repeated 5x across cluster]
# (PoolActor pid=24460) [CV 2/3; 134/150] END classifier__leaf_size=5, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform;, score=-0.984 total time=  14.1s [repeated 2x across cluster]
# (PoolActor pid=24471) [CV 3/3; 132/150] START classifier__leaf_size=3, classifier__n_neighbors=24, classifier__p=2, classifier__weights=distance [repeated 6x across cluster]
# (PoolActor pid=24473) [CV 3/3; 127/150] END classifier__leaf_size=9, classifier__n_neighbors=25, classifier__p=5, classifier__weights=distance;, score=-0.976 total time=  15.6s [repeated 4x across cluster]
# (PoolActor pid=24471) [CV 1/3; 138/150] START classifier__leaf_size=1, classifier__n_neighbors=22, classifier__p=8, classifier__weights=uniform
# (PoolActor pid=24473) [CV 2/3; 138/150] START classifier__leaf_size=1, classifier__n_neighbors=22, classifier__p=8, classifier__weights=uniform
# (PoolActor pid=24464) [CV 1/3; 141/150] END classifier__leaf_size=7, classifier__n_neighbors=29, classifier__p=7, classifier__weights=uniform;, score=-0.916 total time=  13.5s
# (PoolActor pid=24473) [CV 1/3; 133/150] START classifier__leaf_size=1, classifier__n_neighbors=28, classifier__p=2, classifier__weights=distance
# (PoolActor pid=24465) [CV 2/3; 141/150] END classifier__leaf_size=7, classifier__n_neighbors=29, classifier__p=7, classifier__weights=uniform;, score=-0.985 total time=  14.6s
# (PoolActor pid=24470) [CV 2/3; 132/150] START classifier__leaf_size=3, classifier__n_neighbors=24, classifier__p=2, classifier__weights=distance
# (PoolActor pid=24467) [CV 1/3; 142/150] END classifier__leaf_size=3, classifier__n_neighbors=25, classifier__p=5, classifier__weights=distance;, score=-1.047 total time=  13.7s [repeated 9x across cluster]
# (PoolActor pid=24459) [CV 1/3; 134/150] START classifier__leaf_size=5, classifier__n_neighbors=29, classifier__p=8, classifier__weights=uniform [repeated 5x across cluster]
# (PoolActor pid=24471) [CV 1/3; 138/150] END classifier__leaf_size=1, classifier__n_neighbors=22, classifier__p=8, classifier__weights=uniform;, score=-1.147 total time=  12.7s [repeated 5x across cluster]
# (PoolActor pid=24462) [CV 3/3; 145/150] START classifier__leaf_size=8, classifier__n_neighbors=25, classifier__p=2, classifier__weights=distance [repeated 10x across cluster]
# (PoolActor pid=24462) [CV 3/3; 145/150] END classifier__leaf_size=8, classifier__n_neighbors=25, classifier__p=2, classifier__weights=distance;, score=-0.938 total time=   0.2s [repeated 10x across cluster]
# (PoolActor pid=24473) [CV 3/3; 143/150] START classifier__leaf_size=2, classifier__n_neighbors=17, classifier__p=4, classifier__weights=uniform [repeated 3x across cluster]
# (PoolActor pid=24465) [CV 3/3; 146/150] END classifier__leaf_size=3, classifier__n_neighbors=25, classifier__p=3, classifier__weights=uniform;, score=-0.964 total time=  11.9s [repeated 3x across cluster]
# (PoolActor pid=24472) [CV 2/3; 149/150] START classifier__leaf_size=2, classifier__n_neighbors=15, classifier__p=1, classifier__weights=distance
# (PoolActor pid=24470) [CV 3/3; 137/150] END classifier__leaf_size=6, classifier__n_neighbors=22, classifier__p=7, classifier__weights=distance;, score=-1.047 total time=  11.9s
# (PoolActor pid=24459) [CV 2/3; 139/150] START classifier__leaf_size=5, classifier__n_neighbors=19, classifier__p=5, classifier__weights=uniform [repeated 2x across cluster]
# (PoolActor pid=24472) [CV 2/3; 149/150] END classifier__leaf_size=2, classifier__n_neighbors=15, classifier__p=1, classifier__weights=distance;, score=-1.235 total time=   0.6s
# (PoolActor pid=24471) [CV 2/3; 143/150] END classifier__leaf_size=2, classifier__n_neighbors=17, classifier__p=4, classifier__weights=uniform;, score=-1.225 total time=  11.4s [repeated 5x across cluster]
# (PoolActor pid=24473) [CV 1/3; 149/150] START classifier__leaf_size=2, classifier__n_neighbors=15, classifier__p=1, classifier__weights=distance
# (PoolActor pid=24471) [CV 3/3; 148/150] START classifier__leaf_size=5, classifier__n_neighbors=27, classifier__p=4, classifier__weights=uniform
# (PoolActor pid=24473) [CV 1/3; 149/150] END classifier__leaf_size=2, classifier__n_neighbors=15, classifier__p=1, classifier__weights=distance;, score=-1.143 total time=   0.5s
# (PoolActor pid=24470) [CV 2/3; 148/150] START classifier__leaf_size=5, classifier__n_neighbors=27, classifier__p=4, classifier__weights=uniform
# (PoolActor pid=24470) [CV 1/3; 143/150] END classifier__leaf_size=2, classifier__n_neighbors=17, classifier__p=4, classifier__weights=uniform;, score=-1.271 total time=  11.9s [repeated 2x across cluster]
# (PoolActor pid=24459) [CV 3/3; 144/150] START classifier__leaf_size=9, classifier__n_neighbors=16, classifier__p=6, classifier__weights=uniform
# (PoolActor pid=24470) [CV 2/3; 148/150] END classifier__leaf_size=5, classifier__n_neighbors=27, classifier__p=4, classifier__weights=uniform;, score=-1.053 total time=  10.9s [repeated 3x across cluster]
# (PoolActor pid=24459) [CV 1/3; 150/150] START classifier__leaf_size=1, classifier__n_neighbors=22, classifier__p=1, classifier__weights=distance
# (PoolActor pid=24459) [CV 1/3; 150/150] END classifier__leaf_size=1, classifier__n_neighbors=22, classifier__p=1, classifier__weights=distance;, score=-0.982 total time=   0.6s

# %%
output_log_loss = {}
for model_name, model in output_best_esimators.items():

    y_pred_proba = model.predict_proba(X_val)
    y_pred = model.predict(X_val)

    log_loss_score = log_loss(y_val, y_pred_proba)

    output_log_loss[model_name] = log_loss_score

# %%
data = []
for model_name in output_params.keys():
    data.append({
        "model": model_name, 
        "random_search_score": output_scores[model_name], 
        "log_loss_score": output_log_loss[model_name],
        "params": str(output_params[model_name])
    })
output_df = pd.DataFrame(data)
#output_df = output_df.sort_values(by="log_loss_score", ascending=True)
#output_df.to_csv("great_hyperparam_search_result.csv", index=False)
output_df
# Out:
#                     model  random_search_score  log_loss_score  \
# 0                 xgboost            -0.446814        0.428005
# 1                catboost            -0.465396        0.444625
# 2  hist_gradient_boosting            -0.453935        0.434512
# 3       gradient_boosting            -0.453359        0.431684
# 4                     knn            -0.868430        0.861330
#
#                                               params
# 0  {'classifier__subsample': 0.8999999999999999, ...
# 1  {'classifier__min_data_in_leaf': 1, 'classifie...
# 2  {'classifier__min_samples_leaf': 9, 'classifie...
# 3  {'classifier__min_samples_leaf': 7, 'classifie...
# 4  {'classifier__weights': 'uniform', 'classifier...
# (raylet) [2023-12-15 16:25:43,909 E 5760 5800] (raylet) agent_manager.cc:70: The raylet exited immediately because one Ray agent failed, agent_name = dashboard_agent/424238335.
# (raylet) The raylet fate shares with the agent. This can happen because
# (raylet) - The version of `grpcio` doesn't follow Ray's requirement. Agent can segfault with the incorrect `grpcio` version. Check the grpcio version `pip freeze | grep grpcio`.
# (raylet) - The agent failed to start because of unexpected error or port conflict. Read the log `cat /tmp/ray/session_latest/logs/{dashboard_agent|runtime_env_agent}.log`. You can find the log file structure here https://docs.ray.io/en/master/ray-observability/ray-logging.html#logging-directory-structure.
# (raylet) - The agent is killed by the OS (e.g., out of memory).
